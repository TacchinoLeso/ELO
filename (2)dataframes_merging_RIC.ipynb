# %%
import os
import pandas as pd
import numpy as np
from collections import Counter

# Plot libraries
import matplotlib.pyplot as plt
import seaborn as sns
color = sns.color_palette()

# Random seed for reproducibility
seed = 202
np.random.seed(seed)

# Ignore warnings
import warnings
warnings.simplefilter('ignore')

# Garbage collector
import gc
gc.enable()

# %% [markdown]
# ### Import the dataframes

# %% [markdown]
# #### Train and test

# %%
# Train and test
train_df = pd.read_csv("(1)train.csv")
test_df = pd.read_csv("(1)test.csv")
train_df.shape, test_df.shape
# Out:
# ((201917, 6), (123623, 5))

# %%
train_df.head()
# Out:
#   first_active_month          card_id  feature_1  feature_2  feature_3  \
# 0         2017-06-01  C_ID_92a2005557          5          2          1
# 1         2017-01-01  C_ID_3d0044924f          4          1          0
# 2         2016-08-01  C_ID_d639edf6cd          2          2          0
# 3         2017-09-01  C_ID_186d6a6901          4          3          0
# 4         2017-11-01  C_ID_cdbd2c0db2          1          3          0
#
#      target
# 0 -0.820283
# 1  0.392913
# 2  0.688056
# 3  0.142495
# 4 -0.159749

# %% [markdown]
# #### Transactions

# %%
transactions_df = pd.read_csv("(1)transactions.csv")
transactions_df.shape
# Out:
# (30910695, 14)

# %%
transactions_df.head()
# Out:
#    authorized_flag          card_id  city_id  category_1  installments  \
# 0             True  C_ID_4e6213e9bc       88       False             0
# 1             True  C_ID_4e6213e9bc       88       False             0
# 2             True  C_ID_4e6213e9bc       88       False             0
# 3             True  C_ID_4e6213e9bc       88       False             0
# 4             True  C_ID_4e6213e9bc       88       False             0
#
#   category_3  merchant_category_id      merchant_id  month_lag  \
# 0          A                    80  M_ID_e020e9b302         -8
# 1          A                   367  M_ID_86ec983688         -7
# 2          A                    80  M_ID_979ed661fc         -6
# 3          A                   560  M_ID_e6d5ae8ea6         -5
# 4          A                    80  M_ID_e020e9b302        -11
#
#    purchase_amount purchase_date  category_2  state_id  subsector_id
# 0        -0.703331    2017-06-25         1.0        16            37
# 1        -0.733128    2017-07-15         1.0        16            16
# 2        -0.720386    2017-08-09         1.0        16            37
# 3        -0.735352    2017-09-02         1.0        16            34
# 4        -0.722865    2017-03-10         1.0        16            37

# %% [markdown]
# #### Merchants

# %%
merchants_df = pd.read_csv("(1)merchants.csv")
merchants_df.shape
# Out:
# (334620, 22)

# %%
merchants_df.head()
# Out:
#        merchant_id  merchant_group_id  merchant_category_id  subsector_id  \
# 0  M_ID_838061e48c               8353                   792             9
# 1  M_ID_9339d880ad               3184                   840            20
# 2  M_ID_e726bbae1e                447                   690             1
# 3  M_ID_c929bb59af               9514                     2            20
# 4  M_ID_dd3ae3de10              30534                   278            37
#
#    numerical_1  numerical_2  category_1 most_recent_sales_range  \
# 0    -0.057471    -0.057471       False                       E
# 1    -0.057471    -0.057471       False                       E
# 2    -0.057471    -0.057471       False                       E
# 3    -0.057471    -0.057471       False                       E
# 4    -0.057471    -0.057471       False                       E
#
#   most_recent_purchases_range  avg_sales_lag3     ...      avg_sales_lag6  \
# 0                           E           -0.40     ...               -2.25
# 1                           E           -0.72     ...               -0.74
# 2                           E          -82.13     ...              -82.13
# 3                           E        69667.00     ...            69667.00
# 4                           E         5180.00     ...             9830.00
#
#    avg_purchases_lag6  active_months_lag6  avg_sales_lag12  \
# 0           18.666667                   6            -2.32
# 1            1.291667                   6            -0.57
# 2          260.000000                   2           -82.13
# 3            1.000000                   3         69667.00
# 4            4.166667                   6         15826.00
#
#    avg_purchases_lag12  active_months_lag12  category_4  city_id  state_id  \
# 0            13.916667                   12       False      242         9
# 1             1.687500                   12       False       22        16
# 2           260.000000                    2       False       -1         5
# 3             1.000000                    3       False       -1        20
# 4             5.600000                   10        True       11        23
#
#    category_2
# 0         1.0
# 1         1.0
# 2         5.0
# 3         5.0
# 4         2.0
#
# [5 rows x 22 columns]

# %%
#substitute inf values with 2*max_value_in_column
for i in ['3', '6', '12']:
    max_val = max(merchants_df[merchants_df != np.inf]['avg_purchases_lag' + i])
    merchants_df['avg_purchases_lag' + i].replace([np.inf, -np.inf], 2*max_val)

# %% [markdown]
# ### Transactions and Merchants dataframes merging

# %%
print("Number of common merchant_id in merchants_df and transactions_df: %d" % (len(set(transactions_df.merchant_id.unique()).intersection(set(merchants_df.merchant_id.unique())))))
print("merchants_df samples: %d, transactions_df samples: %d" % (merchants_df.shape[0], transactions_df.shape[0]))
# Out:
# Number of common merchant_id in merchants_df and transactions_df: 334620
# merchants_df samples: 334620, transactions_df samples: 30910695

# %%
for c in merchants_df.columns:
    if c not in transactions_df.columns:
        print(c)
# Out:
# merchant_group_id
# numerical_1
# numerical_2
# most_recent_sales_range
# most_recent_purchases_range
# avg_sales_lag3
# avg_purchases_lag3
# active_months_lag3
# avg_sales_lag6
# avg_purchases_lag6
# active_months_lag6
# avg_sales_lag12
# avg_purchases_lag12
# active_months_lag12
# category_4

# %% [markdown]
# Actually, the only meaningfull features to be merged are merchant_group_id, most_recent_sales_range and most_recent_purchases_range

# %% [markdown]
# merchants_df = merchants_df[['merchant_id', "merchant_group_id", "most_recent_sales_range", "most_recent_purchases_range"]]
# merchants_df.columns = ['id', "merchant_group_id", "most_recent_sales_range", "most_recent_purchases_range"]
# merchants_df.head()

# %%
transactions_df = transactions_df.merge(merchants_df, how='left', left_on=['merchant_id', 'city_id', 'category_1', 'category_2', 'merchant_category_id', 'state_id', 'subsector_id'], right_on=['merchant_id', 'city_id', 'category_1', 'category_2', 'merchant_category_id', 'state_id', 'subsector_id'])

# %%
len(transactions_df)
# Out:
# 30910695

# %%
transactions_df.columns
# Out:
# Index(['authorized_flag', 'card_id', 'city_id', 'category_1', 'installments',
#        'category_3', 'merchant_category_id', 'merchant_id', 'month_lag',
#        'purchase_amount', 'purchase_date', 'category_2', 'state_id',
#        'subsector_id', 'merchant_group_id', 'numerical_1', 'numerical_2',
#        'most_recent_sales_range', 'most_recent_purchases_range',
#        'avg_sales_lag3', 'avg_purchases_lag3', 'active_months_lag3',
#        'avg_sales_lag6', 'avg_purchases_lag6', 'active_months_lag6',
#        'avg_sales_lag12', 'avg_purchases_lag12', 'active_months_lag12',
#        'category_4'],
#       dtype='object')

# %% [markdown]
# ## Merge transactions in train and test

# %%
#gdf.head()
#gdf = gdf["purchase_amount"].size().reset_index()
#gdf.columns = ["card_id", "num_hist_transactions"]

# %% [markdown]
# There are a set of duplicated columns (all the couples of the form column_name_x, column_name_y). We can observe that these couples of columns can be merged to obtain a single column with the maximum amount of information. We try to do so for each couple of columns.

# %%
#city_id
#transactions_df['city_id'] = transactions_df['city_id_x']
#transactions_df.drop(labels = ['city_id_x', 'city_id_y'], axis = 1, inplace = True)
#transactions_df.head()

# %%
#category_1

# %%
#merchant_category_id
#transactions_df['merchant_category_id_x'] == transactions_df['merchant_category_id_y']

# %%
#category_2

# %%
#state_id

# %%
#subsector_id

# %%
cat_features = ['purchase_date', 'authorized_flag','city_id', 'category_1','category_3', 'merchant_category_id', 'merchant_id',
                'category_2', 'state_id', 'subsector_id', 'most_recent_sales_range', 'most_recent_purchases_range', 'category_4']
num_features = ['numerical_1', 'numerical_2','installments', 'month_lag', 'purchase_amount', 'avg_sales_lag3', 'avg_purchases_lag3', 'active_months_lag3',
       'avg_sales_lag6', 'avg_purchases_lag6', 'active_months_lag6', 'avg_sales_lag12', 'avg_purchases_lag12', 'active_months_lag12']

# %%
# OLD
# replace mean of num_features and mode of cat_features
def replace_mean_mode(df, num_features, cat_features):
    new_df = pd.DataFrame(columns = df.columns)
    card_ids_unique = np.unique(df['card_id'])
    
    for card_id in card_ids_unique:
        new_line_num = df.loc[df['card_id'] == card_id][num_features].mean()
        new_line_cat = df.loc[df['card_id'] == card_id][cat_features].mode()
        new_df = new_df.append(pd.concat([new_line_num, new_line_cat], axis=1, join='inner'))
        
    new_df['card_id'] = card_ids_unique
    return new_df

# %%
transactions_df.columns
# Out:
# Index(['authorized_flag', 'card_id', 'city_id', 'category_1', 'installments',
#        'category_3', 'merchant_category_id', 'merchant_id', 'month_lag',
#        'purchase_amount', 'purchase_date', 'category_2', 'state_id',
#        'subsector_id', 'merchant_group_id', 'numerical_1', 'numerical_2',
#        'most_recent_sales_range', 'most_recent_purchases_range',
#        'avg_sales_lag3', 'avg_purchases_lag3', 'active_months_lag3',
#        'avg_sales_lag6', 'avg_purchases_lag6', 'active_months_lag6',
#        'avg_sales_lag12', 'avg_purchases_lag12', 'active_months_lag12',
#        'category_4'],
#       dtype='object')

# %%
#new_transactions_df = replace_mean_mode(transactions_df, num_features, cat_features)

# %%
gdf = transactions_df.groupby("card_id")
gdf_num = gdf[num_features].apply(lambda x : np.mean(x))

# %%
gdf_cat = gdf[cat_features].apply(lambda x: x.mode())

# %%
#new_transactions_df = pd.DataFrame(columns = transactions_df.columns)
#cards_ids_unique = np.unique(gdf['card_id'])

#for name, group in df:
#    gdf[num_features].apply(mean)
#    gdf[cat_features].apply(mode)
#    new_transactions_df = new_transactions_df.append(pd.concat([new_line_num, new_line_cat], axis=1, join='inner'))

#df.groupby('A')['C'].apply(sum)
    
#new_transactions_df['card_id'] = card_ids_unique

# %%
gdf_num.head()
# Out:
#                  numerical_1  numerical_2  installments  month_lag  \
# card_id
# C_ID_00007093c1     0.190402     0.157132      1.284768  -5.748344
# C_ID_0001238066     9.879721     9.790741      1.614865  -1.277027
# C_ID_0001506ef0     1.191807     1.028121      0.014925  -4.746269
# C_ID_0001793786     2.838390     2.747739      0.020243  -2.744939
# C_ID_000183fdda     0.189379     0.134690      1.806452  -2.187097
#
#                  purchase_amount  avg_sales_lag3  avg_purchases_lag3  \
# card_id
# C_ID_00007093c1        -0.517706        0.994667            1.013273
# C_ID_0001238066        -0.585114        1.028462            1.050330
# C_ID_0001506ef0        -0.527371        1.052909            1.072006
# C_ID_0001793786        -0.149861        1.307000            1.204146
# C_ID_000183fdda        -0.486637        1.047778            1.046282
#
#                  active_months_lag3  avg_sales_lag6  avg_purchases_lag6  \
# card_id
# C_ID_00007093c1                 3.0        0.992444            1.003570
# C_ID_0001238066                 3.0        1.047094            1.073136
# C_ID_0001506ef0                 3.0        1.071636            1.094685
# C_ID_0001793786                 3.0        1.510571            1.353418
# C_ID_000183fdda                 3.0        1.153333            1.072500
#
#                  active_months_lag6  avg_sales_lag12  avg_purchases_lag12  \
# card_id
# C_ID_00007093c1                 6.0         0.970222             0.994065
# C_ID_0001238066                 6.0         1.079658             1.100800
# C_ID_0001506ef0                 6.0         1.080909             1.115597
# C_ID_0001793786                 6.0         1.600286             1.432265
# C_ID_000183fdda                 6.0         1.103889             1.053809
#
#                  active_months_lag12
# card_id
# C_ID_00007093c1            12.000000
# C_ID_0001238066            11.982906
# C_ID_0001506ef0            12.000000
# C_ID_0001793786            11.957143
# C_ID_000183fdda            12.000000

# %%
gdf_cat.head()
# Out:
#                   purchase_date authorized_flag  city_id category_1  \
# card_id
# C_ID_00007093c1 0    2017-04-17            True    244.0      False
#                 1    2017-04-19             NaN      NaN        NaN
#                 2    2018-01-08             NaN      NaN        NaN
# C_ID_0001238066 0    2017-12-24            True    314.0      False
#                 1    2018-01-23             NaN      NaN        NaN
#
#                   category_3  merchant_category_id      merchant_id  \
# card_id
# C_ID_00007093c1 0          B                 307.0  M_ID_9400cf2342
#                 1        NaN                   NaN              NaN
#                 2        NaN                   NaN              NaN
# C_ID_0001238066 0          B                 307.0  M_ID_d17aabd756
#                 1        NaN                   NaN              NaN
#
#                    category_2  state_id  subsector_id most_recent_sales_range  \
# card_id
# C_ID_00007093c1 0         3.0       2.0          19.0                       A
#                 1         NaN       NaN           NaN                     NaN
#                 2         NaN       NaN           NaN                     NaN
# C_ID_0001238066 0         1.0       9.0          19.0                       C
#                 1         NaN       NaN           NaN                     NaN
#
#                   most_recent_purchases_range category_4
# card_id
# C_ID_00007093c1 0                           A       True
#                 1                         NaN        NaN
#                 2                         NaN        NaN
# C_ID_0001238066 0                           C      False
#                 1                         NaN        NaN

# %%
gdf_num.isnull().sum()
# Out:
# numerical_1            13548
# numerical_2            13548
# installments               0
# month_lag                  0
# purchase_amount            0
# avg_sales_lag3         13548
# avg_purchases_lag3     13548
# active_months_lag3     13548
# avg_sales_lag6         13548
# avg_purchases_lag6     13548
# active_months_lag6     13548
# avg_sales_lag12        13548
# avg_purchases_lag12    13548
# active_months_lag12    13548
# dtype: int64

# %%
gdf_cat.isnull().sum()
# Out:
# purchase_date                  121765
# authorized_flag                429805
# city_id                        426313
# category_1                     429428
# category_3                     428226
# merchant_category_id           392430
# merchant_id                    328101
# category_2                     428794
# state_id                       428434
# subsector_id                   402039
# most_recent_sales_range        415410
# most_recent_purchases_range    414691
# category_4                     440146
# dtype: int64

# %%
gdf_cat.dropna(axis=0, how='any', inplace = True)

# %%
gdf_cat
# Out:
#                   purchase_date authorized_flag  city_id category_1  \
# card_id
# C_ID_00007093c1 0    2017-04-17            True    244.0      False
# C_ID_0001238066 0    2017-12-24            True    314.0      False
# C_ID_0001506ef0 0    2017-12-09            True    137.0      False
# C_ID_0001793786 0    2017-09-14            True    179.0      False
# C_ID_000183fdda 0    2018-02-01            True    161.0      False
# C_ID_00024e244b 0    2017-08-04            True    156.0      False
# C_ID_0002709b5a 0    2017-06-14            True    103.0      False
# C_ID_00027503e2 0    2017-06-07            True    146.0      False
# C_ID_000298032a 0    2017-07-18            True    233.0      False
# C_ID_0002ba3c2e 0    2017-09-01            True    344.0      False
# C_ID_0002c7c2c1 0    2017-11-15            True     69.0      False
# C_ID_00032df08f 0    2017-09-10            True     69.0      False
# C_ID_0003754056 0    2017-08-22            True    303.0      False
# C_ID_000377f6a0 0    2017-12-23            True     76.0      False
# C_ID_0003be3c83 0    2017-08-28            True    279.0      False
# C_ID_0003f41435 0    2017-06-27            True      8.0      False
# C_ID_00042d509c 0    2017-11-23           False     -1.0       True
# C_ID_0004587331 0    2018-01-05            True     87.0      False
# C_ID_0004725b87 0    2017-07-06            True    179.0      False
# C_ID_0004888ddd 0    2017-07-05            True    286.0      False
# C_ID_0004b68c49 0    2017-09-25            True     69.0      False
# C_ID_0004c2a5ab 0    2017-03-04            True     -1.0      False
# C_ID_00057b99fe 0    2017-04-04            True    209.0      False
# C_ID_000599daf9 0    2017-07-13            True    246.0      False
# C_ID_0005b2f279 0    2017-01-29            True     79.0      False
# C_ID_0005f16cc8 0    2018-01-16            True    244.0      False
# C_ID_0006152db8 0    2017-07-01            True    117.0      False
# C_ID_000616f4a8 0    2017-09-06            True    168.0      False
# C_ID_000664aa02 0    2017-12-21            True    314.0      False
# C_ID_00079fec55 0    2017-12-09            True     -1.0       True
# ...                         ...             ...      ...        ...
# C_ID_fffb67f260 0    2018-01-24            True    344.0      False
# C_ID_fffb79fb56 0    2017-03-31            True     21.0      False
# C_ID_fffb9ea3f6 0    2018-02-16            True     76.0      False
# C_ID_fffba72dc5 0    2017-12-02            True     19.0      False
# C_ID_fffbdf036b 0    2017-02-16            True     69.0      False
# C_ID_fffbee5c24 0    2017-04-22            True      4.0      False
# C_ID_fffc96bf24 0    2017-04-03            True     17.0      False
# C_ID_fffcb74f49 0    2017-12-16            True    231.0      False
# C_ID_fffd070e0e 0    2017-01-31            True    250.0      False
# C_ID_fffd1207a8 0    2017-11-11            True     88.0      False
# C_ID_fffd24dcf3 0    2017-11-10            True     69.0      False
# C_ID_fffd337484 0    2017-07-05            True     20.0      False
# C_ID_fffd345048 0    2017-08-08            True    189.0      False
# C_ID_fffd351e7f 0    2017-05-30            True    107.0      False
# C_ID_fffd93c8bf 0    2017-11-03            True    280.0      False
# C_ID_fffd943b91 0    2017-09-10            True     -1.0      False
# C_ID_fffdad8aa0 0    2017-11-11            True    128.0      False
# C_ID_fffde15ab6 0    2017-09-01            True    116.0      False
# C_ID_fffdf34798 0    2017-07-30            True    200.0      False
# C_ID_fffe29a04a 0    2018-01-02            True     90.0      False
# C_ID_fffe78b232 0    2017-01-30            True     19.0      False
# C_ID_fffe866457 0    2017-11-10            True    296.0      False
# C_ID_fffea6de74 0    2017-12-27            True     87.0      False
# C_ID_fffeced303 0    2017-05-06            True     -1.0       True
# C_ID_fffeed3a89 0    2017-12-28            True    143.0      False
# C_ID_ffff1d9928 0    2018-01-08            True    114.0      False
# C_ID_ffff579d3a 0    2017-09-09            True     70.0      False
# C_ID_ffff756266 0    2017-01-26            True    233.0      False
# C_ID_ffff828181 0    2017-02-17            True     96.0      False
# C_ID_fffffd5772 0    2018-02-15            True     20.0      False
#
#                   category_3  merchant_category_id      merchant_id  \
# card_id
# C_ID_00007093c1 0          B                 307.0  M_ID_9400cf2342
# C_ID_0001238066 0          B                 307.0  M_ID_d17aabd756
# C_ID_0001506ef0 0          A                 705.0  M_ID_b1fc88154d
# C_ID_0001793786 0          A                 278.0  M_ID_923d57de8d
# C_ID_000183fdda 0          B                 367.0  M_ID_f9cfe0a43b
# C_ID_00024e244b 0          A                 705.0  M_ID_8f71be2af9
# C_ID_0002709b5a 0          B                 705.0  M_ID_543dd11ce2
# C_ID_00027503e2 0          A                 705.0  M_ID_8de747a1c2
# C_ID_000298032a 0          A                 560.0  M_ID_8978193c15
# C_ID_0002ba3c2e 0          A                 705.0  M_ID_ec1175604c
# C_ID_0002c7c2c1 0          A                 178.0  M_ID_f40ccc1312
# C_ID_00032df08f 0          B                 879.0  M_ID_e93df2c7cc
# C_ID_0003754056 0          A                 705.0  M_ID_d1789c3e5a
# C_ID_000377f6a0 0          A                 130.0  M_ID_d01b1f135a
# C_ID_0003be3c83 0          B                 705.0  M_ID_19171c737a
# C_ID_0003f41435 0          A                 278.0  M_ID_48c7bed0cc
# C_ID_00042d509c 0          B                 879.0  M_ID_9139332ccc
# C_ID_0004587331 0          A                 705.0  M_ID_c55dcf4a06
# C_ID_0004725b87 0          B                 705.0  M_ID_83823fbe67
# C_ID_0004888ddd 0          A                  80.0  M_ID_d69059e2c7
# C_ID_0004b68c49 0          B                 705.0  M_ID_09d7a200d1
# C_ID_0004c2a5ab 0          B                 506.0  M_ID_57df19bf28
# C_ID_00057b99fe 0          A                 307.0  M_ID_5a77e8f1b8
# C_ID_000599daf9 0          A                 367.0  M_ID_2fbdd3f88e
# C_ID_0005b2f279 0          B                 307.0  M_ID_256a900ace
# C_ID_0005f16cc8 0          A                 307.0  M_ID_69423b34e4
# C_ID_0006152db8 0          A                 360.0  M_ID_fbb2a5acf2
# C_ID_000616f4a8 0          B                 278.0  M_ID_719e9d6ad8
# C_ID_000664aa02 0          A                 307.0  M_ID_f67d3a0477
# C_ID_00079fec55 0          B                 839.0  M_ID_e5374dabc0
# ...                      ...                   ...              ...
# C_ID_fffb67f260 0          A                 705.0  M_ID_176a0a915b
# C_ID_fffb79fb56 0          B                 437.0  M_ID_9833b29d8d
# C_ID_fffb9ea3f6 0          A                 705.0  M_ID_c600948e61
# C_ID_fffba72dc5 0          A                  78.0  M_ID_bccfb993bb
# C_ID_fffbdf036b 0          A                 307.0  M_ID_82a30d9203
# C_ID_fffbee5c24 0          C                  68.0  M_ID_63b4207398
# C_ID_fffc96bf24 0          B                 307.0  M_ID_183cdc29e4
# C_ID_fffcb74f49 0          A                 705.0  M_ID_25e9e3043a
# C_ID_fffd070e0e 0          A                 884.0  M_ID_0ff6c1b9c6
# C_ID_fffd1207a8 0          A                 705.0  M_ID_001d92b649
# C_ID_fffd24dcf3 0          C                 690.0  M_ID_3111c6df35
# C_ID_fffd337484 0          C                 383.0  M_ID_656457a8fe
# C_ID_fffd345048 0          A                 705.0  M_ID_06a7783a41
# C_ID_fffd351e7f 0          A                 307.0  M_ID_00a6ca8a8a
# C_ID_fffd93c8bf 0          A                 705.0  M_ID_0cf1eec32f
# C_ID_fffd943b91 0          B                 755.0  M_ID_86be58d7e0
# C_ID_fffdad8aa0 0          A                 278.0  M_ID_50f575c681
# C_ID_fffde15ab6 0          B                 528.0  M_ID_95956c1d44
# C_ID_fffdf34798 0          A                 705.0  M_ID_4c6aaad81c
# C_ID_fffe29a04a 0          A                 307.0  M_ID_51a7b9bb6d
# C_ID_fffe78b232 0          B                 307.0  M_ID_d855771cd9
# C_ID_fffe866457 0          B                 705.0  M_ID_00a6ca8a8a
# C_ID_fffea6de74 0          B                 705.0  M_ID_00a6ca8a8a
# C_ID_fffeced303 0          B                 839.0  M_ID_e5374dabc0
# C_ID_fffeed3a89 0          B                 278.0  M_ID_1704588c56
# C_ID_ffff1d9928 0          B                 705.0  M_ID_cabba1e9ae
# C_ID_ffff579d3a 0          A                  80.0  M_ID_f0ada5d0c0
# C_ID_ffff756266 0          C                 529.0  M_ID_0262bf62a0
# C_ID_ffff828181 0          B                 307.0  M_ID_181cf8c379
# C_ID_fffffd5772 0          B                 755.0  M_ID_445742726b
#
#                    category_2  state_id  subsector_id most_recent_sales_range  \
# card_id
# C_ID_00007093c1 0         3.0       2.0          19.0                       A
# C_ID_0001238066 0         1.0       9.0          19.0                       C
# C_ID_0001506ef0 0         3.0      19.0          33.0                       A
# C_ID_0001793786 0         6.0      -1.0          37.0                       B
# C_ID_000183fdda 0         3.0       3.0          16.0                       B
# C_ID_00024e244b 0         3.0       7.0          33.0                       C
# C_ID_0002709b5a 0         2.0      18.0          33.0                       A
# C_ID_00027503e2 0         3.0      19.0          33.0                       C
# C_ID_000298032a 0         1.0       9.0          34.0                       B
# C_ID_0002ba3c2e 0         2.0      18.0          33.0                       C
# C_ID_0002c7c2c1 0         1.0       9.0          27.0                       A
# C_ID_00032df08f 0         1.0       9.0          29.0                       C
# C_ID_0003754056 0         1.0      15.0          33.0                       B
# C_ID_000377f6a0 0         3.0       2.0          27.0                       C
# C_ID_0003be3c83 0         1.0       9.0          37.0                       B
# C_ID_0003f41435 0         1.0      12.0          37.0                       B
# C_ID_00042d509c 0         6.0      -1.0          29.0                       A
# C_ID_0004587331 0         3.0      11.0          33.0                       A
# C_ID_0004725b87 0         6.0      -1.0          33.0                       E
# C_ID_0004888ddd 0         3.0       3.0          37.0                       A
# C_ID_0004b68c49 0         1.0       9.0          33.0                       A
# C_ID_0004c2a5ab 0         1.0       9.0          29.0                       A
# C_ID_00057b99fe 0         1.0       9.0          19.0                       D
# C_ID_000599daf9 0         3.0       1.0          16.0                       C
# C_ID_0005b2f279 0         1.0      12.0          16.0                       D
# C_ID_0005f16cc8 0         3.0       2.0          19.0                       D
# C_ID_0006152db8 0         4.0      13.0          34.0                       A
# C_ID_000616f4a8 0         1.0       9.0          37.0                       C
# C_ID_000664aa02 0         1.0       9.0          19.0                       D
# C_ID_00079fec55 0         6.0      -1.0          29.0                       A
# ...                       ...       ...           ...                     ...
# C_ID_fffb67f260 0         2.0      18.0          33.0                       C
# C_ID_fffb79fb56 0         1.0       9.0          15.0                       A
# C_ID_fffb9ea3f6 0         3.0       2.0          33.0                       A
# C_ID_fffba72dc5 0         1.0       9.0          23.0                       E
# C_ID_fffbdf036b 0         1.0       9.0          19.0                       A
# C_ID_fffbee5c24 0         2.0      10.0          27.0                       A
# C_ID_fffc96bf24 0         4.0      22.0          21.0                       A
# C_ID_fffcb74f49 0         1.0       9.0          33.0                       B
# C_ID_fffd070e0e 0         1.0       9.0          27.0                       C
# C_ID_fffd1207a8 0         1.0      16.0          37.0                       A
# C_ID_fffd24dcf3 0         1.0       9.0          21.0                       A
# C_ID_fffd337484 0         3.0      19.0           2.0                       D
# C_ID_fffd345048 0         1.0       9.0          33.0                       D
# C_ID_fffd351e7f 0         1.0       4.0          19.0                       C
# C_ID_fffd93c8bf 0         3.0       1.0          33.0                       C
# C_ID_fffd943b91 0         1.0       9.0           8.0                       A
# C_ID_fffdad8aa0 0         1.0       9.0          37.0                       C
# C_ID_fffde15ab6 0         1.0       9.0          25.0                       B
# C_ID_fffdf34798 0         2.0      18.0          33.0                       D
# C_ID_fffe29a04a 0         1.0      15.0          19.0                       D
# C_ID_fffe78b232 0         1.0       9.0          19.0                       C
# C_ID_fffe866457 0         1.0      15.0          33.0                       C
# C_ID_fffea6de74 0         3.0      11.0          37.0                       A
# C_ID_fffeced303 0         6.0      -1.0          29.0                       A
# C_ID_fffeed3a89 0         5.0       5.0          37.0                       C
# C_ID_ffff1d9928 0         4.0       4.0          33.0                       C
# C_ID_ffff579d3a 0         1.0       9.0          37.0                       C
# C_ID_ffff756266 0         1.0       9.0          20.0                       C
# C_ID_ffff828181 0         2.0      24.0          19.0                       B
# C_ID_fffffd5772 0         3.0      19.0           8.0                       A
#
#                   most_recent_purchases_range category_4
# card_id
# C_ID_00007093c1 0                           A       True
# C_ID_0001238066 0                           C      False
# C_ID_0001506ef0 0                           A       True
# C_ID_0001793786 0                           D      False
# C_ID_000183fdda 0                           C       True
# C_ID_00024e244b 0                           D      False
# C_ID_0002709b5a 0                           A       True
# C_ID_00027503e2 0                           C      False
# C_ID_000298032a 0                           D      False
# C_ID_0002ba3c2e 0                           D       True
# C_ID_0002c7c2c1 0                           A       True
# C_ID_00032df08f 0                           A       True
# C_ID_0003754056 0                           B      False
# C_ID_000377f6a0 0                           C       True
# C_ID_0003be3c83 0                           D      False
# C_ID_0003f41435 0                           A      False
# C_ID_00042d509c 0                           A       True
# C_ID_0004587331 0                           B       True
# C_ID_0004725b87 0                           E       True
# C_ID_0004888ddd 0                           A       True
# C_ID_0004b68c49 0                           A       True
# C_ID_0004c2a5ab 0                           A       True
# C_ID_00057b99fe 0                           C      False
# C_ID_000599daf9 0                           A       True
# C_ID_0005b2f279 0                           C      False
# C_ID_0005f16cc8 0                           C       True
# C_ID_0006152db8 0                           A      False
# C_ID_000616f4a8 0                           D      False
# C_ID_000664aa02 0                           C      False
# C_ID_00079fec55 0                           A       True
# ...                                       ...        ...
# C_ID_fffb67f260 0                           C      False
# C_ID_fffb79fb56 0                           B      False
# C_ID_fffb9ea3f6 0                           B       True
# C_ID_fffba72dc5 0                           E      False
# C_ID_fffbdf036b 0                           A       True
# C_ID_fffbee5c24 0                           D       True
# C_ID_fffc96bf24 0                           A       True
# C_ID_fffcb74f49 0                           A      False
# C_ID_fffd070e0e 0                           D      False
# C_ID_fffd1207a8 0                           A       True
# C_ID_fffd24dcf3 0                           A       True
# C_ID_fffd337484 0                           D      False
# C_ID_fffd345048 0                           C      False
# C_ID_fffd351e7f 0                           B      False
# C_ID_fffd93c8bf 0                           D       True
# C_ID_fffd943b91 0                           A       True
# C_ID_fffdad8aa0 0                           C      False
# C_ID_fffde15ab6 0                           C      False
# C_ID_fffdf34798 0                           C       True
# C_ID_fffe29a04a 0                           C      False
# C_ID_fffe78b232 0                           D      False
# C_ID_fffe866457 0                           C      False
# C_ID_fffea6de74 0                           A       True
# C_ID_fffeced303 0                           A       True
# C_ID_fffeed3a89 0                           D       True
# C_ID_ffff1d9928 0                           D      False
# C_ID_ffff579d3a 0                           D      False
# C_ID_ffff756266 0                           C      False
# C_ID_ffff828181 0                           A       True
# C_ID_fffffd5772 0                           A       True
#
# [311992 rows x 13 columns]

# %%
gdf_num.dropna(axis=0, how='any', inplace = True)

# %%
gdf_num
# Out:
#                  numerical_1  numerical_2  installments  month_lag  \
# card_id
# C_ID_00007093c1     0.190402     0.157132      1.284768  -5.748344
# C_ID_0001238066     9.879721     9.790741      1.614865  -1.277027
# C_ID_0001506ef0     1.191807     1.028121      0.014925  -4.746269
# C_ID_0001793786     2.838390     2.747739      0.020243  -2.744939
# C_ID_000183fdda     0.189379     0.134690      1.806452  -2.187097
# C_ID_00024e244b     0.394619     0.334390      0.071429  -6.342857
# C_ID_0002709b5a     0.510012     0.313463      1.710526  -4.105263
# C_ID_00027503e2    -0.004765    -0.006852      0.000000  -4.142857
# C_ID_000298032a     0.237993     0.114652      0.000000  -3.903226
# C_ID_0002ba3c2e    -0.057471    -0.057471      0.000000  -3.123288
# C_ID_0002c7c2c1    15.560765    14.361757      0.000000  -3.328767
# C_ID_00032df08f     6.906065     6.800274      1.276316  -3.651316
# C_ID_fffcb74f49                 3.0        1.001899            1.045408
# C_ID_fffd070e0e                 3.0        1.364138            1.459828
# C_ID_fffd1207a8                 3.0        1.090928            1.116581
# C_ID_fffd24dcf3                 3.0        0.938947            1.034486
# C_ID_fffd337484                 3.0        1.145263            0.971062
# C_ID_fffd345048                 3.0        0.988254            0.994234
# C_ID_fffd351e7f                 3.0        1.149315            1.192691
# C_ID_fffd93c8bf                 3.0        1.027917            1.066347
# C_ID_fffd943b91                 3.0        1.117759            1.104267
# C_ID_fffdad8aa0                 3.0        1.070345            1.091359
# C_ID_fffde15ab6                 3.0        1.018636            1.025086
# C_ID_fffdf34798                 3.0        1.087627            1.064258
# C_ID_fffe29a04a                 3.0        1.080541            1.072553
# C_ID_fffe78b232                 3.0        1.911262            1.968059
# C_ID_fffe866457                 3.0        1.511250            1.552409
# C_ID_fffea6de74                 3.0        1.184459            1.114863
# C_ID_fffeced303                 3.0        0.890520            0.873534
# C_ID_fffeed3a89                 3.0        1.081698            1.092721
# C_ID_ffff1d9928                 3.0        1.039231            1.063558
# C_ID_ffff579d3a                 3.0        1.405732            1.346370
# C_ID_ffff756266                 3.0        1.071176            1.131022
# C_ID_ffff828181                 3.0        0.975517            0.975558
# C_ID_fffffd5772                 3.0        0.984375            0.967563
#
#                  active_months_lag6  avg_sales_lag12  avg_purchases_lag12  \
# card_id
# C_ID_00007093c1            6.000000         0.970222             0.994065
# C_ID_0001238066            6.000000         1.079658             1.100800
# C_ID_0001506ef0            6.000000         1.080909             1.115597
# C_ID_0001793786            6.000000         1.600286             1.432265
# C_ID_000183fdda            6.000000         1.103889             1.053809
# C_ID_00024e244b            6.000000         1.211940             1.157157
# C_ID_0002709b5a            6.000000         1.048824             1.091388
# C_ID_00027503e2            6.000000         1.027632             1.015824
# C_ID_000298032a            6.000000         1.074800             1.078222
# C_ID_0002ba3c2e            6.000000         0.968571             0.985746
# C_ID_0002c7c2c1            6.000000         1.109825             1.166919
# C_ID_00032df08f            6.000000         1.064660             1.108155
# C_ID_0003754056            6.000000         1.075806             1.348026
# C_ID_000377f6a0            6.000000         1.172000             1.121429
# C_ID_0003be3c83            5.933824         1.041324             1.078591
# C_ID_0003f41435            6.000000         1.108667             1.117664
# C_ID_00042d509c            6.000000         0.952000             0.987081
# C_ID_0004587331            6.000000         0.906000             0.914865
# C_ID_0004725b87            6.000000         0.530000             0.552083
# C_ID_0004888ddd            6.000000         0.620000             0.583477
# C_ID_0004b68c49            6.000000         0.973333             0.887008
# C_ID_0004c2a5ab            6.000000         1.505574             1.455958
# C_ID_00057b99fe            6.000000         2.817931             3.259610
# C_ID_000599daf9            6.000000         1.115000             1.093319
# C_ID_0005b2f279            6.000000         1.110000             1.050775
# C_ID_0005f16cc8            6.000000         1.127045             1.155269
# C_ID_0006152db8            6.000000         0.930000             0.928652
# C_ID_000616f4a8            6.000000         1.561579             1.280409
# C_ID_000664aa02            6.000000         1.132609             1.169442
# C_ID_fffbdf036b            12.000000
# C_ID_fffbee5c24            11.666667
# C_ID_fffc96bf24            11.951515
# C_ID_fffcb74f49            11.670886
# C_ID_fffd070e0e            12.000000
# C_ID_fffd1207a8            11.997054
# C_ID_fffd24dcf3            12.000000
# C_ID_fffd337484            12.000000
# C_ID_fffd345048            11.936508
# C_ID_fffd351e7f            11.821918
# C_ID_fffd93c8bf            11.875000
# C_ID_fffd943b91            12.000000
# C_ID_fffdad8aa0            11.862069
# C_ID_fffde15ab6            11.924242
# C_ID_fffdf34798            12.000000
# C_ID_fffe29a04a            11.945946
# C_ID_fffe78b232            12.000000
# C_ID_fffe866457            11.895833
# C_ID_fffea6de74            11.977049
# C_ID_fffeced303            12.000000
# C_ID_fffeed3a89            11.867925
# C_ID_ffff1d9928            12.000000
# C_ID_ffff579d3a            11.975610
# C_ID_ffff756266            12.000000
# C_ID_ffff828181            12.000000
# C_ID_fffffd5772            12.000000
#
# [311992 rows x 14 columns]

# %%
final_transactions_df = pd.merge(gdf_num, gdf_cat, on='card_id')

# %%
final_transactions_df
# Out:
#                  numerical_1  numerical_2  installments  month_lag  \
# card_id
# C_ID_00007093c1     0.190402     0.157132      1.284768  -5.748344
# C_ID_0001238066     9.879721     9.790741      1.614865  -1.277027
# C_ID_0001506ef0     1.191807     1.028121      0.014925  -4.746269
# C_ID_0001793786     2.838390     2.747739      0.020243  -2.744939
# C_ID_000183fdda     0.189379     0.134690      1.806452  -2.187097
# C_ID_00024e244b     0.394619     0.334390      0.071429  -6.342857
# C_ID_0002709b5a     0.510012     0.313463      1.710526  -4.105263
# C_ID_00027503e2    -0.004765    -0.006852      0.000000  -4.142857
# C_ID_000298032a     0.237993     0.114652      0.000000  -3.903226
# C_ID_0002ba3c2e    -0.057471    -0.057471      0.000000  -3.123288
# C_ID_0002c7c2c1    15.560765    14.361757      0.000000  -3.328767
# C_ID_00032df08f     6.906065     6.800274      1.276316  -3.651316
# C_ID_0003754056     0.044237     0.017051      0.000000  -4.594595
# C_ID_000377f6a0     0.758856     0.733078      0.137931  -2.620690
# C_ID_0003be3c83     0.270596     0.258057      1.689266  -3.519774
# C_ID_0003f41435     1.106539     1.061236      0.007547  -4.475472
# C_ID_00042d509c     0.731260     0.706473      1.203125  -1.171875
# C_ID_0004587331     0.005985    -0.051522      0.133333  -0.800000
# C_ID_0004725b87    -0.057471    -0.057471      1.350649  -5.766234
# C_ID_0004888ddd    -0.057471    -0.057471      0.116279  -3.744186
# C_ID_0004b68c49     1.109183    -0.054166      1.285714  -0.571429
# C_ID_0004c2a5ab     2.462540     2.338198      1.546667  -7.546667
# C_ID_00057b99fe    -0.001742    -0.011657      0.000000  -5.500000
# C_ID_000599daf9     0.264268     0.151734      0.000000  -3.113636
# C_ID_0005b2f279    -0.057471    -0.057471      1.000000  -4.812500
# C_ID_0005f16cc8     0.317944     0.302846      0.019355  -4.832258
# C_ID_0006152db8     0.035068     0.035068      0.045455  -3.852273
# C_ID_0001238066                 3.0        1.047094            1.073136
# C_ID_0001506ef0                 3.0        1.071636            1.094685
# C_ID_0001793786                 3.0        1.510571            1.353418
# C_ID_000183fdda                 3.0        1.153333            1.072500
# C_ID_00024e244b                 3.0        1.158806            1.119176
# C_ID_0002709b5a                 3.0        1.025882            1.065267
# C_ID_00027503e2                 3.0        1.015789            1.008729
# C_ID_000298032a                 3.0        1.065600            1.070506
# C_ID_0002ba3c2e                 3.0        0.970000            0.988430
# C_ID_0002c7c2c1                 3.0        1.023860            1.079923
# C_ID_00032df08f                 3.0        1.061456            1.088981
# C_ID_0003754056                 3.0        1.095806            1.421759
# C_ID_000377f6a0                 3.0        1.138667            1.126021
# C_ID_0003be3c83                 3.0        1.024191            1.059273
# C_ID_0003f41435                 3.0        1.083077            1.082781
# C_ID_00042d509c                 3.0        0.958000            0.987866
# C_ID_0004587331                 3.0        0.917333            0.924534
# C_ID_0004725b87                 3.0        0.560000            0.645833
# C_ID_0004888ddd                 3.0        0.810000            0.777814
# C_ID_0004b68c49                 3.0        0.955000            0.936618
# C_ID_0004c2a5ab                 3.0        1.278361            1.272858
# C_ID_00057b99fe                 3.0        1.108276            1.093411
# C_ID_000599daf9                 3.0        1.126500            1.107893
# C_ID_0005b2f279                 3.0        1.030000            1.011275
# C_ID_0005f16cc8                 3.0        1.078636            1.120973
# C_ID_0006152db8                 3.0        0.966667            0.966246
# C_ID_000616f4a8                 3.0        1.414211            1.216780
# C_ID_000664aa02                 3.0        1.073043            1.102025
# C_ID_00079fec55                 3.0        0.841304            0.827211
# ...                             ...             ...                 ...
# C_ID_fffb67f260                 3.0        1.080000            1.089205
# C_ID_fffb79fb56                 3.0        0.997727            0.968189
# C_ID_fffb9ea3f6                 3.0        0.996111            1.022199
# C_ID_fffba72dc5                 3.0        0.831290            0.955511
# C_ID_fffbdf036b                 3.0        1.099167            1.107908
# C_ID_fffbee5c24                 3.0        1.022917            0.970057
# C_ID_fffc96bf24                 3.0        1.274606            1.265240
# C_ID_fffcb74f49                 3.0        1.001899            1.045408
# C_ID_fffd070e0e                 3.0        1.364138            1.459828
# C_ID_fffd1207a8                 3.0        1.090928            1.116581
# C_ID_fffd24dcf3                 3.0        0.938947            1.034486
# C_ID_fffd337484                 3.0        1.145263            0.971062
# C_ID_fffd345048                 3.0        0.988254            0.994234
# C_ID_fffd351e7f                 3.0        1.149315            1.192691
# C_ID_fffd93c8bf                 3.0        1.027917            1.066347
# C_ID_fffd943b91                 3.0        1.117759            1.104267
# C_ID_fffdad8aa0                 3.0        1.070345            1.091359
# C_ID_fffde15ab6                 3.0        1.018636            1.025086
# C_ID_fffdf34798                 3.0        1.087627            1.064258
# C_ID_fffe29a04a                 3.0        1.080541            1.072553
# C_ID_fffe78b232                 3.0        1.911262            1.968059
# C_ID_fffe866457                 3.0        1.511250            1.552409
# C_ID_fffea6de74                 3.0        1.184459            1.114863
# C_ID_fffeced303                 3.0        0.890520            0.873534
# C_ID_fffeed3a89                 3.0        1.081698            1.092721
# C_ID_ffff1d9928                 3.0        1.039231            1.063558
# C_ID_ffff579d3a                 3.0        1.405732            1.346370
# C_ID_ffff756266                 3.0        1.071176            1.131022
# C_ID_ffff828181                 3.0        0.975517            0.975558
# C_ID_fffffd5772                 3.0        0.984375            0.967563
#
#                     ...      category_1  category_3  merchant_category_id  \
# card_id             ...
# C_ID_00007093c1     ...           False           B                 307.0
# C_ID_0001238066     ...           False           B                 307.0
# C_ID_0001506ef0     ...           False           A                 705.0
# C_ID_0001793786     ...           False           A                 278.0
# C_ID_000183fdda     ...           False           B                 367.0
# C_ID_00024e244b     ...           False           A                 705.0
# C_ID_0002709b5a     ...           False           B                 705.0
# C_ID_00027503e2     ...           False           A                 705.0
# C_ID_000298032a     ...           False           A                 560.0
# C_ID_0002ba3c2e     ...           False           A                 705.0
# C_ID_0002c7c2c1     ...           False           A                 178.0
# C_ID_00032df08f     ...           False           B                 879.0
# C_ID_0003754056     ...           False           A                 705.0
# C_ID_000377f6a0     ...           False           A                 130.0
# C_ID_0003be3c83     ...           False           B                 705.0
# C_ID_0003f41435     ...           False           A                 278.0
# C_ID_00042d509c     ...            True           B                 879.0
# C_ID_0004587331     ...           False           A                 705.0
# C_ID_0004725b87     ...           False           B                 705.0
# C_ID_0004888ddd     ...           False           A                  80.0
# C_ID_0004b68c49     ...           False           B                 705.0
# C_ID_0004c2a5ab     ...           False           B                 506.0
# C_ID_00057b99fe     ...           False           A                 307.0
# C_ID_000599daf9     ...           False           A                 367.0
# C_ID_0005b2f279     ...           False           B                 307.0
# C_ID_0005f16cc8     ...           False           A                 307.0
# C_ID_0006152db8     ...           False           A                 360.0
# C_ID_000616f4a8     ...           False           B                 278.0
# C_ID_000664aa02     ...           False           A                 307.0
# C_ID_00079fec55     ...            True           B                 839.0
# ...                 ...             ...         ...                   ...
# C_ID_fffb67f260     ...           False           A                 705.0
# C_ID_fffb79fb56     ...           False           B                 437.0
# C_ID_fffb9ea3f6     ...           False           A                 705.0
# C_ID_fffba72dc5     ...           False           A                  78.0
# C_ID_fffbdf036b     ...           False           A                 307.0
# C_ID_fffbee5c24     ...           False           C                  68.0
# C_ID_fffc96bf24     ...           False           B                 307.0
# C_ID_fffcb74f49     ...           False           A                 705.0
# C_ID_fffd070e0e     ...           False           A                 884.0
# C_ID_fffd1207a8     ...           False           A                 705.0
# C_ID_fffd24dcf3     ...           False           C                 690.0
# C_ID_fffd337484     ...           False           C                 383.0
# C_ID_fffd345048     ...           False           A                 705.0
# C_ID_fffd351e7f     ...           False           A                 307.0
# C_ID_fffd93c8bf     ...           False           A                 705.0
# C_ID_fffd943b91     ...           False           B                 755.0
# C_ID_fffdad8aa0     ...           False           A                 278.0
# C_ID_fffde15ab6     ...           False           B                 528.0
# C_ID_fffdf34798     ...           False           A                 705.0
# C_ID_fffe29a04a     ...           False           A                 307.0
# C_ID_fffe78b232     ...           False           B                 307.0
# C_ID_fffe866457     ...           False           B                 705.0
# C_ID_fffba72dc5  M_ID_bccfb993bb        1.0      9.0          23.0
# C_ID_fffbdf036b  M_ID_82a30d9203        1.0      9.0          19.0
# C_ID_fffbee5c24  M_ID_63b4207398        2.0     10.0          27.0
# C_ID_fffc96bf24  M_ID_183cdc29e4        4.0     22.0          21.0
# C_ID_fffcb74f49  M_ID_25e9e3043a        1.0      9.0          33.0
# C_ID_fffd070e0e  M_ID_0ff6c1b9c6        1.0      9.0          27.0
# C_ID_fffd1207a8  M_ID_001d92b649        1.0     16.0          37.0
# C_ID_fffd24dcf3  M_ID_3111c6df35        1.0      9.0          21.0
# C_ID_fffd337484  M_ID_656457a8fe        3.0     19.0           2.0
# C_ID_fffd345048  M_ID_06a7783a41        1.0      9.0          33.0
# C_ID_fffd351e7f  M_ID_00a6ca8a8a        1.0      4.0          19.0
# C_ID_fffd93c8bf  M_ID_0cf1eec32f        3.0      1.0          33.0
# C_ID_fffd943b91  M_ID_86be58d7e0        1.0      9.0           8.0
# C_ID_fffdad8aa0  M_ID_50f575c681        1.0      9.0          37.0
# C_ID_fffde15ab6  M_ID_95956c1d44        1.0      9.0          25.0
# C_ID_fffdf34798  M_ID_4c6aaad81c        2.0     18.0          33.0
# C_ID_fffe29a04a  M_ID_51a7b9bb6d        1.0     15.0          19.0
# C_ID_fffe78b232  M_ID_d855771cd9        1.0      9.0          19.0
# C_ID_fffe866457  M_ID_00a6ca8a8a        1.0     15.0          33.0
# C_ID_fffea6de74  M_ID_00a6ca8a8a        3.0     11.0          37.0
# C_ID_fffeced303  M_ID_e5374dabc0        6.0     -1.0          29.0
# C_ID_fffeed3a89  M_ID_1704588c56        5.0      5.0          37.0
# C_ID_ffff1d9928  M_ID_cabba1e9ae        4.0      4.0          33.0
# C_ID_ffff579d3a  M_ID_f0ada5d0c0        1.0      9.0          37.0
# C_ID_ffff756266  M_ID_0262bf62a0        1.0      9.0          20.0
# C_ID_ffff828181  M_ID_181cf8c379        2.0     24.0          19.0
# C_ID_fffffd5772  M_ID_445742726b        3.0     19.0           8.0
#
#                 most_recent_sales_range most_recent_purchases_range  \
# card_id
# C_ID_00007093c1                       A                           A
# C_ID_0001238066                       C                           C
# C_ID_0001506ef0                       A                           A
# C_ID_0001793786                       B                           D
# C_ID_000183fdda                       B                           C
# C_ID_00024e244b                       C                           D
# C_ID_0002709b5a                       A                           A
# C_ID_00027503e2                       C                           C
# C_ID_000298032a                       B                           D
# C_ID_0002ba3c2e                       C                           D
# C_ID_0002c7c2c1                       A                           A
# C_ID_00032df08f                       C                           A
# C_ID_0003754056                       B                           B
# C_ID_000377f6a0                       C                           C
# C_ID_0003be3c83                       B                           D
# C_ID_0003f41435                       B                           A
# C_ID_00042d509c                       A                           A
# C_ID_0004587331                       A                           B
# C_ID_0004725b87                       E                           E
# C_ID_0004888ddd                       A                           A
# C_ID_0004b68c49                       A                           A
# C_ID_0004c2a5ab                       A                           A
# C_ID_00057b99fe                       D                           C
# C_ID_000599daf9                       C                           A
# C_ID_0005b2f279                       D                           C
# C_ID_0005f16cc8                       D                           C
# C_ID_0006152db8                       A                           A
# C_ID_000616f4a8                       C                           D
# C_ID_000664aa02                       D                           C
# C_ID_00079fec55                       A                           A
# ...                                 ...                         ...
# C_ID_fffb67f260                       C                           C
# C_ID_fffb79fb56                       A                           B
# C_ID_fffb9ea3f6                       A                           B
# C_ID_fffba72dc5                       E                           E
# C_ID_fffbdf036b                       A                           A
# C_ID_fffbee5c24                       A                           D
# C_ID_fffc96bf24                       A                           A
# C_ID_fffcb74f49                       B                           A
# C_ID_fffd070e0e                       C                           D
# C_ID_fffd1207a8                       A                           A
# C_ID_fffd24dcf3                       A                           A
# C_ID_fffd337484                       D                           D
# C_ID_fffd345048                       D                           C
# C_ID_fffd351e7f                       C                           B
# C_ID_fffd93c8bf                       C                           D
# C_ID_fffd943b91                       A                           A
# C_ID_fffdad8aa0                       C                           C
# C_ID_fffde15ab6                       B                           C
# C_ID_fffdf34798                       D                           C
# C_ID_fffe29a04a                       D                           C
# C_ID_fffe78b232                       C                           D
# C_ID_fffe866457                       C                           C
# C_ID_fffea6de74                       A                           A
# C_ID_fffeced303                       A                           A
# C_ID_fffeed3a89                       C                           D
# C_ID_ffff1d9928                       C                           D
# C_ID_ffff579d3a                       C                           D
# C_ID_ffff756266                       C                           C
# C_ID_ffff828181                       B                           A
# C_ID_fffffd5772                       A                           A
#
#                  category_4
# card_id
# C_ID_00007093c1        True
# C_ID_0001238066       False
# C_ID_0001506ef0        True
# C_ID_0001793786       False
# C_ID_000183fdda        True
# C_ID_00024e244b       False
# C_ID_0002709b5a        True
# C_ID_00027503e2       False
# C_ID_000298032a       False
# C_ID_0002ba3c2e        True
# C_ID_0002c7c2c1        True
# C_ID_00032df08f        True
# C_ID_0003754056       False
# C_ID_000377f6a0        True
# C_ID_0003be3c83       False
# C_ID_0003f41435       False
# C_ID_00042d509c        True
# C_ID_0004587331        True
# C_ID_0004725b87        True
# C_ID_0004888ddd        True
# C_ID_0004b68c49        True
# C_ID_0004c2a5ab        True
# C_ID_00057b99fe       False
# C_ID_000599daf9        True
# C_ID_0005b2f279       False
# C_ID_0005f16cc8        True
# C_ID_0006152db8       False
# C_ID_000616f4a8       False
# C_ID_000664aa02       False
# C_ID_00079fec55        True
# ...                     ...
# C_ID_fffb67f260       False
# C_ID_fffb79fb56       False
# C_ID_fffb9ea3f6        True
# C_ID_fffba72dc5       False
# C_ID_fffbdf036b        True
# C_ID_fffbee5c24        True
# C_ID_fffc96bf24        True
# C_ID_fffcb74f49       False
# C_ID_fffd070e0e       False
# C_ID_fffd1207a8        True
# C_ID_fffd24dcf3        True
# C_ID_fffd337484       False
# C_ID_fffd345048       False
# C_ID_fffd351e7f       False
# C_ID_fffd93c8bf        True
# C_ID_fffd943b91        True
# C_ID_fffdad8aa0       False
# C_ID_fffde15ab6       False
# C_ID_fffdf34798        True
# C_ID_fffe29a04a       False
# C_ID_fffe78b232       False
# C_ID_fffe866457       False
# C_ID_fffea6de74        True
# C_ID_fffeced303        True
# C_ID_fffeed3a89        True
# C_ID_ffff1d9928       False
# C_ID_ffff579d3a       False
# C_ID_ffff756266       False
# C_ID_ffff828181        True
# C_ID_fffffd5772        True
#
# [311992 rows x 27 columns]

# %% [markdown]
# #### Train

# %%
new_train_df = pd.merge(train_df, final_transactions_df, on="card_id", how="left")

# %%
new_train_df.head()
# Out:
#   first_active_month          card_id  feature_1  feature_2  feature_3  \
# 0         2017-06-01  C_ID_92a2005557          5          2          1
# 1         2017-01-01  C_ID_3d0044924f          4          1          0
# 2         2016-08-01  C_ID_d639edf6cd          2          2          0
# 3         2017-09-01  C_ID_186d6a6901          4          3          0
# 4         2017-11-01  C_ID_cdbd2c0db2          1          3          0
#
#      target  numerical_1  numerical_2  installments  month_lag     ...      \
# 0 -0.820283    18.290382    17.688792      0.014440  -3.530686     ...
# 1  0.392913    30.047451    29.385934      1.542135  -4.921348     ...
# 2  0.688056     0.814297     0.637316      0.000000  -8.363636     ...
# 3  0.142495     4.787462     4.687412      1.059524  -2.452381     ...
# 4 -0.159749     3.765944     3.705154      1.285714  -0.678571     ...
#
#    category_1  category_3  merchant_category_id      merchant_id  category_2  \
# 0       False           A                 560.0  M_ID_1a81c358a3         1.0
# 1       False           B                 307.0  M_ID_940fb4498f         1.0
# 2       False           A                 705.0  M_ID_5634fd83e0         5.0
# 3       False           B                 278.0  M_ID_00a6ca8a8a         4.0
# 4       False           B                 278.0  M_ID_cecefd9589         4.0
#
#    state_id  subsector_id  most_recent_sales_range  \
# 0       9.0          34.0                        C
# 1       9.0          34.0                        A
# 2       5.0          33.0                        A
# 3      22.0          37.0                        A
# 4      22.0          37.0                        D
#
#    most_recent_purchases_range  category_4
# 0                            A        True
# 1                            A        True
# 2                            A        True
# 3                            A        True
# 4                            D        True
#
# [5 rows x 33 columns]

# %%
new_train_df.shape
# Out:
# (201917, 33)

# %%
new_train_df.isnull().sum()
# Out:
# first_active_month                0
# card_id                           0
# feature_1                         0
# feature_2                         0
# feature_3                         0
# target                            0
# numerical_1                    8317
# numerical_2                    8317
# installments                   8317
# month_lag                      8317
# purchase_amount                8317
# avg_sales_lag3                 8317
# avg_purchases_lag3             8317
# active_months_lag3             8317
# avg_sales_lag6                 8317
# avg_purchases_lag6             8317
# active_months_lag6             8317
# avg_sales_lag12                8317
# avg_purchases_lag12            8317
# active_months_lag12            8317
# purchase_date                  8317
# authorized_flag                8317
# city_id                        8317
# category_1                     8317
# category_3                     8317
# merchant_category_id           8317
# merchant_id                    8317
# category_2                     8317
# state_id                       8317
# subsector_id                   8317
# most_recent_sales_range        8317
# most_recent_purchases_range    8317
# category_4                     8317
# dtype: int64

# %%
#save card_id of rows with at least one null value in a variable before dropping those rows
null_train_ids = new_train_df[new_train_df.isnull().any(axis=1)]['card_id']

# %%
#new_train_df.drop_duplicates(inplace = True)

# %%
#this is actually not necessary, since we will use the original (1)train.csv to train the model for this case in the test set
#new_null_train_df = train_df[train_df.card_id in null_train_ids]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-7fec444be6c0> in <module>()
#       1 #this is actually not necessary, since we will use the original (1)train.csv to train the model for this case in the test set
# ----> 2 new_null_train_df = train_df[train_df.card_id in null_train_ids]
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/generic.py in __contains__(self, key)
#    1517     def __contains__(self, key):
#    1518         """True if the key is in the info axis"""
# -> 1519         return key in self._info_axis
#    1520
#    1521     @property
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in __contains__(self, key)
#    2018     @Appender(_index_shared_docs['__contains__'] % _index_doc_kwargs)
#    2019     def __contains__(self, key):
# -> 2020         hash(key)
#    2021         try:
#    2022             return key in self._engine
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/generic.py in __hash__(self)
#    1487     def __hash__(self):
#    1488         raise TypeError('{0!r} objects are mutable, thus they cannot be'
# -> 1489                         ' hashed'.format(self.__class__.__name__))
#    1490
#    1491     def __iter__(self):
#
# TypeError: 'Series' objects are mutable, thus they cannot be hashed

# %%
new_train_df.dropna(axis=0, how='any', inplace = True)

# %%
new_train_df.to_csv('(2)small_train.csv', index = False)

# %% [markdown]
# #### Test

# %%
new_test_df = pd.merge(test_df, final_transactions_df, on="card_id", how="left")

# %%
new_test_df.isnull().sum()
# Out:
# first_active_month                0
# card_id                           0
# feature_1                         0
# feature_2                         0
# feature_3                         0
# numerical_1                    5231
# numerical_2                    5231
# installments                   5231
# month_lag                      5231
# purchase_amount                5231
# avg_sales_lag3                 5231
# avg_purchases_lag3             5231
# active_months_lag3             5231
# avg_sales_lag6                 5231
# avg_purchases_lag6             5231
# active_months_lag6             5231
# avg_sales_lag12                5231
# avg_purchases_lag12            5231
# active_months_lag12            5231
# purchase_date                  5231
# authorized_flag                5231
# city_id                        5231
# category_1                     5231
# category_3                     5231
# merchant_category_id           5231
# merchant_id                    5231
# category_2                     5231
# state_id                       5231
# subsector_id                   5231
# most_recent_sales_range        5231
# most_recent_purchases_range    5231
# category_4                     5231
# dtype: int64

# %%
#sum(test_df['card_id'].isin(gdf['card_id']) == False)

# %% [markdown]
# C'è un problema: 5231 card_id del test non corrispondono a alcuna entry in final_trasactions_df. Forse ce ne siamo persi alcuni per strada, o forse semplicemente non c'erano dall'inizio. Per risolvere il problema, i card_id dei 5231 sono salvati in una variabile e le righe del test set originale corrispondenti salvate in un dataframe. Così facendo, possiamo usare le righe complete per trainare un modello in grado di fare predizioni su tutte le righe del test set tranne le 5231 in questione, che vengono predette da un algoritmo trainato sul train set originale (senza informazioni estratte da merchants e/o transactions)

# %%
null_test_ids = new_test_df[new_test_df.isnull().any(axis=1)]['card_id']

# %%
new_test_df.dropna(axis=0, how='any', inplace = True)

# %%
new_null_test_df = test_df.loc[test_df.card_id.isin(null_test_ids)]

# %%
new_null_test_df
# Out:
#        first_active_month          card_id  feature_1  feature_2  feature_3
# 71             2017-02-01  C_ID_ac88d17815          2          2          0
# 138            2017-08-01  C_ID_e1e8acdab6          3          2          1
# 153            2015-02-01  C_ID_d99a6ea9e0          3          3          1
# 167            2017-02-01  C_ID_f9bd6c67b0          3          3          1
# 171            2016-04-01  C_ID_4bf0426f57          4          2          0
# 196            2017-01-01  C_ID_fb28b161c5          4          2          0
# 231            2017-10-01  C_ID_5f1eda7477          2          1          0
# 271            2017-12-01  C_ID_004885878b          3          2          1
# 354            2016-12-01  C_ID_2f1f3ea8c6          2          2          0
# 357            2017-06-01  C_ID_c02e054feb          3          3          1
# 392            2017-07-01  C_ID_54b2846a36          2          1          0
# 434            2014-04-01  C_ID_4c7fc71084          3          3          1
# 497            2016-01-01  C_ID_225a5abc31          4          2          0
# 524            2016-12-01  C_ID_0302f33b8f          2          2          0
# 554            2016-09-01  C_ID_34bf4ce0c8          3          1          1
# 612            2017-11-01  C_ID_1de37c1871          3          1          1
# 627            2016-07-01  C_ID_d248a9b767          3          3          1
# 634            2017-05-01  C_ID_66422419e7          3          2          1
# 675            2017-07-01  C_ID_92a14249ea          3          2          1
# 684            2017-10-01  C_ID_cedf04e754          2          2          0
# 719            2017-08-01  C_ID_1d30638e7e          2          1          0
# 739            2017-12-01  C_ID_d97e8cea4b          3          1          1
# 751            2017-04-01  C_ID_7a2ef519f1          3          2          1
# 766            2017-06-01  C_ID_3c42224b5d          2          2          0
# 839            2017-01-01  C_ID_7215809b01          2          2          0
# 930            2017-07-01  C_ID_c8de29e24f          3          2          1
# 966            2017-05-01  C_ID_9a55868ff1          3          3          1
# 970            2017-11-01  C_ID_7b082ef549          2          2          0
# 971            2017-10-01  C_ID_8793484b70          3          2          1
# 986            2016-11-01  C_ID_6902c9dc76          4          2          0
# ...                   ...              ...        ...        ...        ...
# 123037         2016-09-01  C_ID_8556e6b3b3          2          2          0
# 123055         2017-09-01  C_ID_afbb60a7b0          2          1          0
# 123066         2017-02-01  C_ID_742521ebbd          1          2          0
# 123067         2017-11-01  C_ID_c98d601568          4          3          0
# 123079         2016-12-01  C_ID_01e686f224          3          2          1
# 123094         2016-08-01  C_ID_bc5ce56532          4          2          0
# 123095         2017-11-01  C_ID_664179fa6f          3          1          1
# 123099         2016-12-01  C_ID_a2659c5784          3          1          1
# 123103         2016-10-01  C_ID_df35725b22          5          1          1
# 123105         2017-07-01  C_ID_3119ac8b63          3          3          1
# 123136         2017-08-01  C_ID_9bc0143030          2          2          0
# 123178         2017-05-01  C_ID_721198bcb7          3          2          1
# 123220         2016-12-01  C_ID_3468b8721c          5          2          1
# 123246         2016-11-01  C_ID_5fd014a4ed          3          2          1
# 123285         2017-06-01  C_ID_764c9e279b          2          1          0
# 123303         2017-10-01  C_ID_8fbf9527b1          3          3          1
# 123306         2016-10-01  C_ID_804b36480b          3          3          1
# 123316         2017-12-01  C_ID_ff75f010a7          5          1          1
# 123339         2016-04-01  C_ID_9b8663dcfb          5          1          1
# 123357         2017-03-01  C_ID_6775dd5279          2          1          0
# 123374         2017-05-01  C_ID_cfbe802a57          3          2          1
# 123384         2015-05-01  C_ID_5f7fddd9fa          5          1          1
# 123391         2015-11-01  C_ID_ae4c244deb          3          3          1
# 123405         2017-08-01  C_ID_145158d72a          3          2          1
# 123421         2015-11-01  C_ID_b491e3f1cb          4          2          0
# 123431         2017-05-01  C_ID_a65fa7c944          3          3          1
# 123454         2015-05-01  C_ID_b70757178d          3          3          1
# 123492         2016-11-01  C_ID_4cfffebc6f          5          1          1
# 123577         2017-07-01  C_ID_1525314fe7          2          1          0
# 123614         2017-01-01  C_ID_7147e348c3          5          2          1
#
# [5231 rows x 5 columns]

# %%
new_test_df.to_csv('(2)small_test.csv', index = False)

# %%
new_null_test_df.to_csv('(2)small_null_test.csv', index = False)
