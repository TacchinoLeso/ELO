# %%
import pandas as pd
import numpy as np
# Plot libraries
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.metrics import mean_squared_error
from math import sqrt

# Random seed for reproducibility
seed = 202
np.random.seed(seed)

# Ignore warnings
import warnings
warnings.simplefilter('ignore')

# Garbage collector
import gc
gc.enable()

# %%
# Import the preprocessed dataframes
train_df = pd.read_csv("(2)small_train.csv")
test_df = pd.read_csv("(2)small_test.csv")
train_df.shape, test_df.shape
# Out:
# ((201917, 32), (123623, 31))

# %%
train_df.head()
# Out:
#   first_active_month          card_id  feature_1  feature_2  feature_3  \
# 0         2017-06-01  C_ID_92a2005557          5          2          1
# 1         2017-01-01  C_ID_3d0044924f          4          1          0
# 2         2016-08-01  C_ID_d639edf6cd          2          2          0
# 3         2017-09-01  C_ID_186d6a6901          4          3          0
# 4         2017-11-01  C_ID_cdbd2c0db2          1          3          0
#
#      target  transactions_count  authorized_transactions_sum  \
# 0 -0.820283                 277                        265.0
# 1  0.392913                 356                        345.0
# 2  0.688056                  44                         42.0
# 3  0.142495                  84                         84.0
# 4 -0.159749                 168                        163.0
#
#    authorized_transactions_mean  city_id_nunique  \
# 0                      0.956679                9
# 1                      0.969101                9
# 2                      0.954545                5
# 3                      1.000000                7
# 4                      0.970238                7
#
#                   ...                   month_lag_mean  month_lag_max  \
# 0                 ...                        -3.530686              2
# 1                 ...                        -4.921348              2
# 2                 ...                        -8.363636              2
# 3                 ...                        -2.452381              2
# 4                 ...                        -0.678571              2
#
#    month_lag_min  purchase_date_nunique  category_2_nunique  state_id_nunique  \
# 0             -8                    170                   2                 3
# 1            -12                    207                   2                 3
# 2            -13                     35                   2                 2
# 3             -5                     54                   3                 5
# 4             -3                    104                   5                 7
#
#    subsector_id_nunique  merchant_group_id_nunique  \
# 0                    21                         88
# 1                    24                        107
# 2                     8                         10
# 3                    15                         43
# 4                    18                         80
#
#    most_recent_sales_range_nunique  most_recent_purchases_range_nunique
# 0                                5                                    5
# 1                                5                                    5
# 2                                4                                    5
# 3                                5                                    5
# 4                                5                                    5
#
# [5 rows x 32 columns]

# %% [markdown]
# ### Feature engineering

# %%
def add_temporal_features(df):
    df['first_active_month'] = pd.to_datetime(df['first_active_month'])
    df['month'] = df['first_active_month'].dt.month
    df['year'] = df['first_active_month'].dt.year
    return df

# %%
def feature_engineering(df):
    df = add_temporal_features(df)
    return df

# %%
train_df = feature_engineering(train_df)
test_df = feature_engineering(test_df)

# %%
train_df.head()
# Out:
#   first_active_month          card_id  feature_1  feature_2  feature_3  \
# 0         2017-06-01  C_ID_92a2005557          5          2          1
# 1         2017-01-01  C_ID_3d0044924f          4          1          0
# 2         2016-08-01  C_ID_d639edf6cd          2          2          0
# 3         2017-09-01  C_ID_186d6a6901          4          3          0
# 4         2017-11-01  C_ID_cdbd2c0db2          1          3          0
#
#      target  transactions_count  authorized_transactions_sum  \
# 0 -0.820283                 277                        265.0
# 1  0.392913                 356                        345.0
# 2  0.688056                  44                         42.0
# 3  0.142495                  84                         84.0
# 4 -0.159749                 168                        163.0
#
#    authorized_transactions_mean  city_id_nunique  ...   month_lag_min  \
# 0                      0.956679                9  ...              -8
# 1                      0.969101                9  ...             -12
# 2                      0.954545                5  ...             -13
# 3                      1.000000                7  ...              -5
# 4                      0.970238                7  ...              -3
#
#    purchase_date_nunique  category_2_nunique  state_id_nunique  \
# 0                    170                   2                 3
# 1                    207                   2                 3
# 2                     35                   2                 2
# 3                     54                   3                 5
# 4                    104                   5                 7
#
#    subsector_id_nunique  merchant_group_id_nunique  \
# 0                    21                         88
# 1                    24                        107
# 2                     8                         10
# 3                    15                         43
# 4                    18                         80
#
#    most_recent_sales_range_nunique  most_recent_purchases_range_nunique  \
# 0                                5                                    5
# 1                                5                                    5
# 2                                4                                    5
# 3                                5                                    5
# 4                                5                                    5
#
#    month  year
# 0      6  2017
# 1      1  2017
# 2      8  2016
# 3      9  2017
# 4     11  2017
#
# [5 rows x 34 columns]

# %% [markdown]
# ### Export dataframes

# %%
train_df.to_csv('(3)small_train.csv', index = False)
test_df.to_csv('(3)small_test.csv', index = False)
