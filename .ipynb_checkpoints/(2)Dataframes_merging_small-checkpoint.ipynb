# %%
import os
import pandas as pd
import numpy as np
from collections import Counter

# Plot libraries
import matplotlib.pyplot as plt
import seaborn as sns
color = sns.color_palette()

# Random seed for reproducibility
seed = 202
np.random.seed(seed)

# Ignore warnings
import warnings
warnings.simplefilter('ignore')

# Garbage collector
import gc
gc.enable()

# %% [markdown]
# ### Import the dataframes

# %% [markdown]
# #### Train and test

# %%
# Train and test
train_df = pd.read_csv("(1)train.csv")
test_df = pd.read_csv("(1)test.csv")
train_df.shape, test_df.shape
# Out:
# ((201917, 6), (123623, 5))

# %%
train_df.head()
# Out:
#   first_active_month          card_id  feature_1  feature_2  feature_3  \
# 0         2017-06-01  C_ID_92a2005557          5          2          1
# 1         2017-01-01  C_ID_3d0044924f          4          1          0
# 2         2016-08-01  C_ID_d639edf6cd          2          2          0
# 3         2017-09-01  C_ID_186d6a6901          4          3          0
# 4         2017-11-01  C_ID_cdbd2c0db2          1          3          0
#
#      target
# 0 -0.820283
# 1  0.392913
# 2  0.688056
# 3  0.142495
# 4 -0.159749

# %% [markdown]
# #### Transactions

# %%
transactions_df = pd.read_csv("(1)transactions.csv")
transactions_df.shape
# Out:
# (30910695, 14)

# %%
transactions_df.head()
# Out:
#    authorized_flag          card_id  city_id  category_1  installments  \
# 0             True  C_ID_4e6213e9bc       88       False             0
# 1             True  C_ID_4e6213e9bc       88       False             0
# 2             True  C_ID_4e6213e9bc       88       False             0
# 3             True  C_ID_4e6213e9bc       88       False             0
# 4             True  C_ID_4e6213e9bc       88       False             0
#
#   category_3  merchant_category_id      merchant_id  month_lag  \
# 0          A                    80  M_ID_e020e9b302         -8
# 1          A                   367  M_ID_86ec983688         -7
# 2          A                    80  M_ID_979ed661fc         -6
# 3          A                   560  M_ID_e6d5ae8ea6         -5
# 4          A                    80  M_ID_e020e9b302        -11
#
#    purchase_amount purchase_date  category_2  state_id  subsector_id
# 0        -0.703331    2017-06-25         1.0        16            37
# 1        -0.733128    2017-07-15         1.0        16            16
# 2        -0.720386    2017-08-09         1.0        16            37
# 3        -0.735352    2017-09-02         1.0        16            34
# 4        -0.722865    2017-03-10         1.0        16            37

# %% [markdown]
# #### Merchants

# %%
merchants_df = pd.read_csv("(1)merchants.csv")
merchants_df.shape
# Out:
# (334620, 22)

# %%
merchants_df.head()
# Out:
#        merchant_id  merchant_group_id  merchant_category_id  subsector_id  \
# 0  M_ID_838061e48c               8353                   792             9
# 1  M_ID_9339d880ad               3184                   840            20
# 2  M_ID_e726bbae1e                447                   690             1
# 3  M_ID_c929bb59af               9514                     2            20
# 4  M_ID_dd3ae3de10              30534                   278            37
#
#    numerical_1  numerical_2  category_1 most_recent_sales_range  \
# 0    -0.057471    -0.057471       False                       E
# 1    -0.057471    -0.057471       False                       E
# 2    -0.057471    -0.057471       False                       E
# 3    -0.057471    -0.057471       False                       E
# 4    -0.057471    -0.057471       False                       E
#
#   most_recent_purchases_range  avg_sales_lag3     ...      avg_sales_lag6  \
# 0                           E           -0.40     ...               -2.25
# 1                           E           -0.72     ...               -0.74
# 2                           E          -82.13     ...              -82.13
# 3                           E        69667.00     ...            69667.00
# 4                           E         5180.00     ...             9830.00
#
#    avg_purchases_lag6  active_months_lag6  avg_sales_lag12  \
# 0           18.666667                   6            -2.32
# 1            1.291667                   6            -0.57
# 2          260.000000                   2           -82.13
# 3            1.000000                   3         69667.00
# 4            4.166667                   6         15826.00
#
#    avg_purchases_lag12  active_months_lag12  category_4  city_id  state_id  \
# 0            13.916667                   12       False      242         9
# 1             1.687500                   12       False       22        16
# 2           260.000000                    2       False       -1         5
# 3             1.000000                    3       False       -1        20
# 4             5.600000                   10        True       11        23
#
#    category_2
# 0         1.0
# 1         1.0
# 2         5.0
# 3         5.0
# 4         2.0
#
# [5 rows x 22 columns]

# %%
#substitute inf values with 2*max_value_in_column
for i in ['3', '6', '12']:
    max_val = max(merchants_df[merchants_df != np.inf]['avg_purchases_lag' + i])
    merchants_df['avg_purchases_lag' + i].replace([np.inf, -np.inf], 2*max_val)

# %% [markdown]
# ### Transactions and Merchants dataframes merging

# %%
print("Number of common merchant_id in merchants_df and transactions_df: %d" % (len(set(transactions_df.merchant_id.unique()).intersection(set(merchants_df.merchant_id.unique())))))
print("merchants_df samples: %d, transactions_df samples: %d" % (merchants_df.shape[0], transactions_df.shape[0]))
# Out:
# Number of common merchant_id in merchants_df and transactions_df: 334620
# merchants_df samples: 334620, transactions_df samples: 30910695

# %%
for c in merchants_df.columns:
    if c not in transactions_df.columns:
        print(c)
# Out:
# merchant_group_id
# numerical_1
# numerical_2
# most_recent_sales_range
# most_recent_purchases_range
# avg_sales_lag3
# avg_purchases_lag3
# active_months_lag3
# avg_sales_lag6
# avg_purchases_lag6
# active_months_lag6
# avg_sales_lag12
# avg_purchases_lag12
# active_months_lag12
# category_4

# %% [markdown]
# Actually, the only meaningfull features to be merged are merchant_group_id, most_recent_sales_range and most_recent_purchases_range

# %% [markdown]
# merchants_df = merchants_df[['merchant_id', "merchant_group_id", "most_recent_sales_range", "most_recent_purchases_range"]]
# merchants_df.columns = ['id', "merchant_group_id", "most_recent_sales_range", "most_recent_purchases_range"]
# merchants_df.head()

# %%
transactions_df = transactions_df.merge(merchants_df, how='left', left_on=['merchant_id', 'city_id', 'category_1', 'category_2', 'merchant_category_id', 'state_id', 'subsector_id'], right_on=['merchant_id', 'city_id', 'category_1', 'category_2', 'merchant_category_id', 'state_id', 'subsector_id'])

# %%
len(transactions_df)
# Out:
# 30910695

# %%
transactions_df.columns
# Out:
# Index(['authorized_flag', 'card_id', 'city_id', 'category_1', 'installments',
#        'category_3', 'merchant_category_id', 'merchant_id', 'month_lag',
#        'purchase_amount', 'purchase_date', 'category_2', 'state_id',
#        'subsector_id', 'merchant_group_id', 'numerical_1', 'numerical_2',
#        'most_recent_sales_range', 'most_recent_purchases_range',
#        'avg_sales_lag3', 'avg_purchases_lag3', 'active_months_lag3',
#        'avg_sales_lag6', 'avg_purchases_lag6', 'active_months_lag6',
#        'avg_sales_lag12', 'avg_purchases_lag12', 'active_months_lag12',
#        'category_4'],
#       dtype='object')

# %% [markdown]
# ## Merge transactions in train and test

# %%
gdf.head()
#gdf = gdf["purchase_amount"].size().reset_index()
#gdf.columns = ["card_id", "num_hist_transactions"]
# Out:
#           authorized_flag          card_id  city_id  category_1  installments  \
# 0                    True  C_ID_4e6213e9bc       88       False             0
# 1                    True  C_ID_4e6213e9bc       88       False             0
# 2                    True  C_ID_4e6213e9bc       88       False             0
# 3                    True  C_ID_4e6213e9bc       88       False             0
# 4                    True  C_ID_4e6213e9bc       88       False             0
# 394                 False  C_ID_5037ff576e      322       False             1
# 395                  True  C_ID_5037ff576e      138       False             1
# 396                  True  C_ID_5037ff576e      138       False             1
# 397                  True  C_ID_5037ff576e      226       False             1
# 398                  True  C_ID_5037ff576e      330       False             1
# 512                  True  C_ID_0e171c1b48       69       False             0
# 513                  True  C_ID_0e171c1b48      277       False             0
# 514                  True  C_ID_0e171c1b48      277       False             0
# 515                  True  C_ID_0e171c1b48      277       False             0
# 516                 False  C_ID_0e171c1b48      277       False             0
# 790                  True  C_ID_48fb13e70f       -1        True             1
# 791                  True  C_ID_48fb13e70f       69       False             1
# 792                  True  C_ID_48fb13e70f       69       False             1
# 793                  True  C_ID_48fb13e70f       -1        True             1
# 794                  True  C_ID_48fb13e70f       69       False             1
# 869                  True  C_ID_fc8e41b9cf       69       False             1
# 870                  True  C_ID_fc8e41b9cf      170       False             1
# 871                  True  C_ID_fc8e41b9cf       69       False             1
# 872                  True  C_ID_fc8e41b9cf      251       False             3
# 873                  True  C_ID_fc8e41b9cf      251       False             1
# 1110                 True  C_ID_b02e55aa9d       96       False             0
# 1111                 True  C_ID_b02e55aa9d      283       False             0
# 1112                 True  C_ID_b02e55aa9d      283       False             0
# 1113                 True  C_ID_b02e55aa9d      283       False             0
# 1114                False  C_ID_b02e55aa9d      283       False             0
# ...                   ...              ...      ...         ...           ...
# 30906251             True  C_ID_e9a43776a3       -1        True             2
# 30906369             True  C_ID_942719068e       88       False             0
# 30906392             True  C_ID_7abe7e8632       69       False             1
# 30906410             True  C_ID_58e7355da2       -1        True             1
# 30906448             True  C_ID_a414317bfd       69       False             1
# 30906449             True  C_ID_a414317bfd      179       False             1
# 30906455             True  C_ID_8468bf25d4       -1        True             1
# 30907006             True  C_ID_58380a09e1      264       False             1
# 30907213             True  C_ID_a78baeca00       -1        True             3
# 30907226             True  C_ID_0d6f572a45      331       False             1
# 30907328             True  C_ID_f1fc434f32      331       False             0
# 30907818             True  C_ID_a4bc0c0ad2      140       False             1
# 30907965             True  C_ID_521ababc6e      333       False             1
# 30908033             True  C_ID_354e3e6dc8      251       False             0
# 30908050             True  C_ID_1f5a328c58      117       False             0
# 30908382             True  C_ID_d41fc0f265       69       False             1
# 30908423             True  C_ID_da78806b00       -1        True             1
# 30908662             True  C_ID_c295c42f08       -1        True             3
# 30908663             True  C_ID_c295c42f08       -1        True             1
# 30908831             True  C_ID_a0c776add1       -1        True             6
# 30909365             True  C_ID_f5755ba02c       -1        True             1
# 30909562             True  C_ID_2495cce89d       -1        True             1
# 30909638             True  C_ID_cfde762d6f       -1        True             1
# 30909806             True  C_ID_b31438ec30      244       False             0
# 30909948             True  C_ID_5c9c173cfe       17       False             0
# 30909976             True  C_ID_d18a9d2fe9       -1        True             1
# 30909977             True  C_ID_d104ec08c4      216       False             0
# 30910032             True  C_ID_e5b7ba41cf       -1        True             1
# 30910126             True  C_ID_6d34cb789c       41       False            -1
# 30910688             True  C_ID_0509e85404      322       False             1
#
#          category_3  merchant_category_id      merchant_id  month_lag  \
# 0                 A                    80  M_ID_e020e9b302         -8
# 1                 A                   367  M_ID_86ec983688         -7
# 2                 A                    80  M_ID_979ed661fc         -6
# 3                 A                   560  M_ID_e6d5ae8ea6         -5
# 4                 A                    80  M_ID_e020e9b302        -11
# 394               B                   278  M_ID_b61c7d1be0         -3
# 395               B                   307  M_ID_fe69229f24         -4
# 396               B                   705  M_ID_efc106141c         -9
# 397               B                   307  M_ID_708022307c         -4
# 398               B                   705  M_ID_393b4b8cec         -9
# 512               A                   879  M_ID_00a6ca8a8a         -1
# 513               A                   703  M_ID_4d6321ce13         -1
# 514               A                   683  M_ID_22360595e6        -11
# 515               A                   561  M_ID_67ead1197d         -3
# 516               A                   511  M_ID_0f8e964477        -10
# 790               B                   879  M_ID_9139332ccc         -2
# 791               B                   560  M_ID_2f6d08eaca         -8
# 792               B                   544  M_ID_7306a369ea         -8
# 793               B                   839  M_ID_50076f761c         -5
# 794               B                   278  M_ID_f86439cec0         -5
# 869               B                   879  M_ID_00a6ca8a8a         -5
# 870               B                   367  M_ID_68e26f3cca         -1
# 871               B                   879  M_ID_00a6ca8a8a         -2
# 872               C                   126  M_ID_25abfd10aa         -5
# 873               B                   309  M_ID_c2d9240309         -2
# 1110              A                   278  M_ID_8894ecfe89         -4
# 1111              A                   278  M_ID_cdabc86023         -7
# 1112              A                   111  M_ID_1440c83173        -13
# 1113              A                   367  M_ID_3339c5faa9         -9
# 1114              A                    80  M_ID_3214ef1be2         -9
# ...             ...                   ...              ...        ...
# 30906251          C                   544  M_ID_cdba603e7c          1
# 30906369          A                   840  M_ID_ca6128f3d8          1
# 30906392          B                   307  M_ID_559180aef0          1
# 30906410          B                   879  M_ID_9139332ccc          2
# 30906448          B                   302  M_ID_784417e169          1
# 30906449          B                   222  M_ID_7c0fb7f95c          2
# 30906455          B                   661  M_ID_fc7d7969c3          1
# 30907006          B                   705  M_ID_d3d9c017eb          2
# 30907213          C                   690  M_ID_3111c6df35          2
# 30907226          B                   705  M_ID_0e8d93dd86          2
# 30907328          A                   705  M_ID_77e2942cd8          2
# 30907818          B                   307  M_ID_a216ec6d06          1
# 30907965          B                   307  M_ID_3beb5cc157          2
# 30908033          A                   529  M_ID_8a7841faf9          1
# 30908050          A                   813  M_ID_b5e8daf772          1
# 30908382          B                   387  M_ID_1c6d0800e8          1
# 30908423          B                   661  M_ID_fc7d7969c3          2
# 30908662          C                   879  M_ID_00a6ca8a8a          2
# 30908663          B                   491  M_ID_79692349d6          1
# 30908831          C                   806  M_ID_44d0154c81          1
# 30909365          B                   661  M_ID_fc7d7969c3          1
# 30909562          B                   879  M_ID_9139332ccc          2
# 30909638          B                   302  M_ID_b9f9332438          1
# 30909806          A                   434  M_ID_f46a6367ca          1
# 30909948          A                   705  M_ID_d7d5019c60          1
# 30909976          B                   661  M_ID_fc7d7969c3          1
# 30909977          A                   307  M_ID_ef8673e53b          2
# 30910032          B                   879  M_ID_9139332ccc          1
# 30910126          D                   274  M_ID_e2f6434278          1
# 30910688          B                   705  M_ID_531bc3b325          2
#
#           purchase_amount     ...     avg_sales_lag3  avg_purchases_lag3  \
# 0               -0.703331     ...               1.08            1.082451
# 1               -0.733128     ...               1.06            1.052071
# 2               -0.720386     ...               0.98            0.974653
# 3               -0.735352     ...               1.00            1.053443
# 4               -0.722865     ...               1.08            1.082451
# 394             -0.595260     ...                NaN                 NaN
# 395              1.189469     ...                NaN                 NaN
# 396             -0.640069     ...                NaN                 NaN
# 397             -0.652256     ...                NaN                 NaN
# 398             -0.674210     ...                NaN                 NaN
# 512             -0.728876     ...                NaN                 NaN
# 513             -0.662759     ...                NaN                 NaN
# 514             -0.730379     ...               1.11            1.160071
# 515             -0.694315     ...                NaN                 NaN
# 516             -0.740146     ...                NaN                 NaN
# 790             -0.649837     ...                NaN                 NaN
# 791             -0.689206     ...               1.06            1.033645
# 792             -0.670378     ...               0.96            0.974946
# 793             -0.596793     ...               0.94            0.950611
# 794             -0.661407     ...               1.08            1.092926
# 869             -0.423838     ...                NaN                 NaN
# 870             -0.728876     ...                NaN                 NaN
# 871             -0.686802     ...                NaN                 NaN
# 872             -0.070715     ...               0.96            1.017007
# 873             -0.719860     ...               0.97            0.986310
# 1110            -0.733384     ...               4.66            4.214689
# 1111            -0.704263     ...                NaN                 NaN
# 1112            -0.717005     ...               1.47            1.330033
# 1113            -0.739485     ...               1.04            1.031947
# 1114            -0.736765     ...               0.98            1.005810
# ...                   ...     ...                ...                 ...
# 30906251        -0.577649     ...               0.74            0.805316
# 30906369        -0.617830     ...                NaN                 NaN
# 30906392        -0.646230     ...               1.11            1.098170
# 30906410        -0.734135     ...                NaN                 NaN
# 30906448        -0.431351     ...                NaN                 NaN
# 30906449        -0.475830     ...                NaN                 NaN
# 30906455        -0.717005     ...               0.88            0.890464
# 30907006        -0.708260     ...                NaN                 NaN
# 30907213        -0.146208     ...               0.95            0.997999
# 30907226        -0.603825     ...                NaN                 NaN
# 30907328        -0.714751     ...                NaN                 NaN
# 30907818        -0.731881     ...                NaN                 NaN
# 30907965        -0.566590     ...                NaN                 NaN
# 30908033        -0.686802     ...               0.97            1.107468
# 30908050        -0.686802     ...                NaN                 NaN
# 30908382        -0.431351     ...               0.96            0.994444
# 30908423        -0.746893     ...               0.88            0.890464
# 30908662        -0.701843     ...                NaN                 NaN
# 30908663        -0.461855     ...               0.95            0.828665
# 30908831         2.512793     ...               1.06            1.048276
# 30909365        -0.717005     ...               0.88            0.890464
# 30909562         1.777546     ...                NaN                 NaN
# 30909638         2.304706     ...                NaN                 NaN
# 30909806        -0.190927     ...                NaN                 NaN
# 30909948        -0.734887     ...               1.08            1.044870
# 30909976        -0.745405     ...               0.88            0.890464
# 30909977        -0.439135     ...               1.12            1.201715
# 30910032        -0.461434     ...                NaN                 NaN
# 30910126        -0.581616     ...                NaN                 NaN
# 30910688        -0.182166     ...                NaN                 NaN
#
#           active_months_lag3  avg_sales_lag6  avg_purchases_lag6  \
# 0                        3.0            1.14            1.114135
# 1                        3.0            1.06            1.058605
# 2                        3.0            0.98            0.967058
# 3                        3.0            0.88            0.897406
# 4                        3.0            1.14            1.114135
# 394                      NaN             NaN                 NaN
# 395                      NaN             NaN                 NaN
# 396                      NaN             NaN                 NaN
# 397                      NaN             NaN                 NaN
# 398                      NaN             NaN                 NaN
# 512                      NaN             NaN                 NaN
# 513                      NaN             NaN                 NaN
# 514                      3.0            1.13            1.174727
# 515                      NaN             NaN                 NaN
# 516                      NaN             NaN                 NaN
# 790                      NaN             NaN                 NaN
# 791                      3.0            1.03            1.004361
# 792                      3.0            0.99            0.998318
# 793                      3.0            0.94            0.930489
# 794                      3.0            1.09            1.095924
# 869                      NaN             NaN                 NaN
# 870                      NaN             NaN                 NaN
# 871                      NaN             NaN                 NaN
# 872                      3.0            1.12            1.299320
# 873                      3.0            1.07            1.007589
# 1110                     3.0            5.47            4.858757
# 1111                     NaN             NaN                 NaN
# 1112                     3.0            1.60            1.413641
# 1113                     3.0            1.02            1.007987
# 1114                     3.0            1.03            1.055963
# ...                      ...             ...                 ...
# 30906251                 3.0            0.67            0.728089
# 30906369                 NaN             NaN                 NaN
# 30906392                 3.0            1.03            1.079312
# 30906410                 NaN             NaN                 NaN
# 30906448                 NaN             NaN                 NaN
# 30906449                 NaN             NaN                 NaN
# 30906455                 3.0            0.72            0.737107
# 30907006                 NaN             NaN                 NaN
# 30907213                 3.0            0.90            0.967786
# 30907226                 NaN             NaN                 NaN
# 30907328                 NaN             NaN                 NaN
# 30907818                 NaN             NaN                 NaN
# 30907965                 NaN             NaN                 NaN
# 30908033                 3.0            0.79            0.888889
# 30908050                 NaN             NaN                 NaN
# 30908382                 3.0            3.38            1.602778
# 30908423                 3.0            0.72            0.737107
# 30908662                 NaN             NaN                 NaN
# 30908663                 3.0            0.88            0.724008
# 30908831                 3.0            1.14            1.021073
# 30909365                 3.0            0.72            0.737107
# 30909562                 NaN             NaN                 NaN
# 30909638                 NaN             NaN                 NaN
# 30909806                 NaN             NaN                 NaN
# 30909948                 3.0            1.06            1.020381
# 30909976                 3.0            0.72            0.737107
# 30909977                 3.0            1.11            1.260514
# 30910032                 NaN             NaN                 NaN
# 30910126                 NaN             NaN                 NaN
# 30910688                 NaN             NaN                 NaN
#
#           active_months_lag6  avg_sales_lag12 avg_purchases_lag12  \
# 0                        6.0             1.19            1.156844
# 1                        6.0             1.05            1.062087
# 2                        6.0             0.97            0.956668
# 3                        6.0             0.86            0.864394
# 4                        6.0             1.19            1.156844
# 394                      NaN              NaN                 NaN
# 395                      NaN              NaN                 NaN
# 396                      NaN              NaN                 NaN
# 397                      NaN              NaN                 NaN
# 398                      NaN              NaN                 NaN
# 512                      NaN              NaN                 NaN
# 513                      NaN              NaN                 NaN
# 514                      6.0             1.19            1.226067
# 515                      NaN              NaN                 NaN
# 516                      NaN              NaN                 NaN
# 790                      NaN              NaN                 NaN
# 791                      6.0             1.05            1.025078
# 792                      6.0             1.04            1.023464
# 793                      6.0             0.84            0.865628
# 794                      6.0             1.13            1.125829
# 869                      NaN              NaN                 NaN
# 870                      NaN              NaN                 NaN
# 871                      NaN              NaN                 NaN
# 872                      6.0             1.27            1.362148
# 873                      6.0             1.11            1.021705
# 1110                     6.0             5.70            4.977401
# 1111                     NaN              NaN                 NaN
# 1112                     6.0             1.60            1.407805
# 1113                     6.0             0.98            0.990977
# 1114                     6.0             1.12            1.151682
# ...                      ...              ...                 ...
# 30906251                 6.0             0.63            0.695881
# 30906369                 NaN              NaN                 NaN
# 30906392                 6.0             1.02            1.099972
# 30906410                 NaN              NaN                 NaN
# 30906448                 NaN              NaN                 NaN
# 30906449                 NaN              NaN                 NaN
# 30906455                 6.0             0.56            0.585596
# 30907006                 NaN              NaN                 NaN
# 30907213                 6.0             0.79            0.891154
# 30907226                 NaN              NaN                 NaN
# 30907328                 NaN              NaN                 NaN
# 30907818                 NaN              NaN                 NaN
# 30907965                 NaN              NaN                 NaN
# 30908033                 6.0             0.67            0.733607
# 30908050                 NaN              NaN                 NaN
# 30908382                 6.0             2.35            1.326389
# 30908423                 6.0             0.56            0.585596
# 30908662                 NaN              NaN                 NaN
# 30908663                 6.0             0.77            0.619400
# 30908831                 6.0             1.01            0.902107
# 30909365                 6.0             0.56            0.585596
# 30909562                 NaN              NaN                 NaN
# 30909638                 NaN              NaN                 NaN
# 30909806                 NaN              NaN                 NaN
# 30909948                 6.0             1.05            0.978475
# 30909976                 6.0             0.56            0.585596
# 30909977                 6.0             1.04            1.232969
# 30910032                 NaN              NaN                 NaN
# 30910126                 NaN              NaN                 NaN
# 30910688                 NaN              NaN                 NaN
#
#          active_months_lag12  category_4
# 0                       12.0        True
# 1                       12.0        True
# 2                       12.0        True
# 3                       12.0        True
# 4                       12.0        True
# 394                      NaN         NaN
# 395                      NaN         NaN
# 396                      NaN         NaN
# 397                      NaN         NaN
# 398                      NaN         NaN
# 512                      NaN         NaN
# 513                      NaN         NaN
# 514                     12.0        True
# 515                      NaN         NaN
# 516                      NaN         NaN
# 790                      NaN         NaN
# 791                     12.0        True
# 792                     12.0        True
# 793                     12.0        True
# 794                     12.0        True
# 869                      NaN         NaN
# 870                      NaN         NaN
# 871                      NaN         NaN
# 872                     12.0        True
# 873                     12.0        True
# 1110                    12.0       False
# 1111                     NaN         NaN
# 1112                    12.0       False
# 1113                    12.0       False
# 1114                    12.0       False
# ...                      ...         ...
# 30906251                 9.0        True
# 30906369                 NaN         NaN
# 30906392                12.0        True
# 30906410                 NaN         NaN
# 30906448                 NaN         NaN
# 30906449                 NaN         NaN
# 30906455                12.0        True
# 30907006                 NaN         NaN
# 30907213                12.0        True
# 30907226                 NaN         NaN
# 30907328                 NaN         NaN
# 30907818                 NaN         NaN
# 30907965                 NaN         NaN
# 30908033                12.0        True
# 30908050                 NaN         NaN
# 30908382                12.0        True
# 30908423                12.0        True
# 30908662                 NaN         NaN
# 30908663                12.0        True
# 30908831                12.0        True
# 30909365                12.0        True
# 30909562                 NaN         NaN
# 30909638                 NaN         NaN
# 30909806                 NaN         NaN
# 30909948                10.0        True
# 30909976                12.0        True
# 30909977                12.0       False
# 30910032                 NaN         NaN
# 30910126                 NaN         NaN
# 30910688                 NaN         NaN
#
# [1626990 rows x 29 columns]

# %% [markdown]
# There are a set of duplicated columns (all the couples of the form column_name_x, column_name_y). We can observe that these couples of columns can be merged to obtain a single column with the maximum amount of information. We try to do so for each couple of columns.

# %%
#city_id
#transactions_df['city_id'] = transactions_df['city_id_x']
#transactions_df.drop(labels = ['city_id_x', 'city_id_y'], axis = 1, inplace = True)
#transactions_df.head()

# %%
#category_1

# %%
#merchant_category_id
#transactions_df['merchant_category_id_x'] == transactions_df['merchant_category_id_y']

# %%
#category_2

# %%
#state_id

# %%
#subsector_id

# %%
cat_features = ['authorized_flag','city_id', 'category_1','category_3', 'merchant_category_id', 'merchant_id',
                'category_2', 'state_id', 'subsector_id', 'merchant_group_id', 'most_recent_sales_range', 'most_recent_purchases_range', 'category_4']
num_features = ['numerical_1', 'numerical_2','installments', 'month_lag', 'purchase_amount', 'avg_sales_lag3', 'avg_purchases_lag3', 'active_months_lag3',
       'avg_sales_lag6', 'avg_purchases_lag6', 'active_months_lag6', 'avg_sales_lag12', 'avg_purchases_lag12', 'active_months_lag12']

# %%
# OLD
# replace mean of num_features and mode of cat_features
def replace_mean_mode(df, num_features, cat_features):
    new_df = pd.DataFrame(columns = df.columns)
    card_ids_unique = np.unique(df['card_id'])
    
    for card_id in card_ids_unique:
        new_line_num = df.loc[df['card_id'] == card_id][num_features].mean()
        new_line_cat = df.loc[df['card_id'] == card_id][cat_features].mode()
        new_df = new_df.append(pd.concat([new_line_num, new_line_cat], axis=1, join='inner'))
        
    new_df['card_id'] = card_ids_unique
    return new_df

# %%
transactions_df.columns

# %%
#new_transactions_df = replace_mean_mode(transactions_df, num_features, cat_features)

# %%
gdf = transactions_df.groupby("card_id")
gdf[num_features].apply(np.mean, result_type = 'reduce')
gdf[cat_features].apply(lambda x: x.mode(), result_type = 'reduce')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in apply(self, func, *args, **kwargs)
#     917             try:
# --> 918                 result = self._python_apply_general(f)
#     919             except Exception:
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in _python_apply_general(self, f)
#     935         keys, values, mutated = self.grouper.apply(f, self._selected_obj,
# --> 936                                                    self.axis)
#     937
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in apply(self, f, data, axis)
#    2272             group_axes = _get_axes(group)
# -> 2273             res = f(group)
#    2274             if not _is_indexed_like(res, group_axes):
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in f(g)
#     907                     with np.errstate(all='ignore'):
# --> 908                         return func(g, *args, **kwargs)
#     909             else:
#
# TypeError: mean() got an unexpected keyword argument 'result_type'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-2382959e7f9a> in <module>()
#       1 gdf = transactions_df.groupby("card_id")
# ----> 2 gdf[num_features].apply(np.mean, result_type = 'reduce')
#       3 gdf[cat_features].apply(lambda x: x.mode(), result_type = 'reduce')
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in apply(self, func, *args, **kwargs)
#     928
#     929                 with _group_selection_context(self):
# --> 930                     return self._python_apply_general(f)
#     931
#     932         return result
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in _python_apply_general(self, f)
#     934     def _python_apply_general(self, f):
#     935         keys, values, mutated = self.grouper.apply(f, self._selected_obj,
# --> 936                                                    self.axis)
#     937
#     938         return self._wrap_applied_output(
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in apply(self, f, data, axis)
#    2271             # group might be modified
#    2272             group_axes = _get_axes(group)
# -> 2273             res = f(group)
#    2274             if not _is_indexed_like(res, group_axes):
#    2275                 mutated = True
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in f(g)
#     906                 def f(g):
#     907                     with np.errstate(all='ignore'):
# --> 908                         return func(g, *args, **kwargs)
#     909             else:
#     910                 raise ValueError('func must be a callable if args or '
#
# TypeError: mean() got an unexpected keyword argument 'result_type'

# %%
#new_transactions_df = pd.DataFrame(columns = transactions_df.columns)
#cards_ids_unique = np.unique(gdf['card_id'])

#for name, group in df:
#    gdf[num_features].apply(mean)
#    gdf[cat_features].apply(mode)
#    new_transactions_df = new_transactions_df.append(pd.concat([new_line_num, new_line_cat], axis=1, join='inner'))

#df.groupby('A')['C'].apply(sum)
    
#new_transactions_df['card_id'] = card_ids_unique

# %%
gdf.head()
# Out:
#           authorized_flag          card_id  city_id  category_1  installments  \
# 0                    True  C_ID_4e6213e9bc       88       False             0
# 1                    True  C_ID_4e6213e9bc       88       False             0
# 2                    True  C_ID_4e6213e9bc       88       False             0
# 3                    True  C_ID_4e6213e9bc       88       False             0
# 4                    True  C_ID_4e6213e9bc       88       False             0
# 394                 False  C_ID_5037ff576e      322       False             1
# 395                  True  C_ID_5037ff576e      138       False             1
# 396                  True  C_ID_5037ff576e      138       False             1
# 397                  True  C_ID_5037ff576e      226       False             1
# 398                  True  C_ID_5037ff576e      330       False             1
# 512                  True  C_ID_0e171c1b48       69       False             0
# 513                  True  C_ID_0e171c1b48      277       False             0
# 514                  True  C_ID_0e171c1b48      277       False             0
# 515                  True  C_ID_0e171c1b48      277       False             0
# 516                 False  C_ID_0e171c1b48      277       False             0
# 790                  True  C_ID_48fb13e70f       -1        True             1
# 791                  True  C_ID_48fb13e70f       69       False             1
# 792                  True  C_ID_48fb13e70f       69       False             1
# 793                  True  C_ID_48fb13e70f       -1        True             1
# 794                  True  C_ID_48fb13e70f       69       False             1
# 869                  True  C_ID_fc8e41b9cf       69       False             1
# 870                  True  C_ID_fc8e41b9cf      170       False             1
# 871                  True  C_ID_fc8e41b9cf       69       False             1
# 872                  True  C_ID_fc8e41b9cf      251       False             3
# 873                  True  C_ID_fc8e41b9cf      251       False             1
# 1110                 True  C_ID_b02e55aa9d       96       False             0
# 1111                 True  C_ID_b02e55aa9d      283       False             0
# 1112                 True  C_ID_b02e55aa9d      283       False             0
# 1113                 True  C_ID_b02e55aa9d      283       False             0
# 1114                False  C_ID_b02e55aa9d      283       False             0
# ...                   ...              ...      ...         ...           ...
# 30906251             True  C_ID_e9a43776a3       -1        True             2
# 30906369             True  C_ID_942719068e       88       False             0
# 30906392             True  C_ID_7abe7e8632       69       False             1
# 30906410             True  C_ID_58e7355da2       -1        True             1
# 30906448             True  C_ID_a414317bfd       69       False             1
# 30906449             True  C_ID_a414317bfd      179       False             1
# 30906455             True  C_ID_8468bf25d4       -1        True             1
# 30907006             True  C_ID_58380a09e1      264       False             1
# 30907213             True  C_ID_a78baeca00       -1        True             3
# 30907226             True  C_ID_0d6f572a45      331       False             1
# 30907328             True  C_ID_f1fc434f32      331       False             0
# 30907818             True  C_ID_a4bc0c0ad2      140       False             1
# 30907965             True  C_ID_521ababc6e      333       False             1
# 30908033             True  C_ID_354e3e6dc8      251       False             0
# 30908050             True  C_ID_1f5a328c58      117       False             0
# 30908382             True  C_ID_d41fc0f265       69       False             1
# 30908423             True  C_ID_da78806b00       -1        True             1
# 30908662             True  C_ID_c295c42f08       -1        True             3
# 30908663             True  C_ID_c295c42f08       -1        True             1
# 30908831             True  C_ID_a0c776add1       -1        True             6
# 30909365             True  C_ID_f5755ba02c       -1        True             1
# 30909562             True  C_ID_2495cce89d       -1        True             1
# 30909638             True  C_ID_cfde762d6f       -1        True             1
# 30909806             True  C_ID_b31438ec30      244       False             0
# 30909948             True  C_ID_5c9c173cfe       17       False             0
# 30909976             True  C_ID_d18a9d2fe9       -1        True             1
# 30909977             True  C_ID_d104ec08c4      216       False             0
# 30910032             True  C_ID_e5b7ba41cf       -1        True             1
# 30910126             True  C_ID_6d34cb789c       41       False            -1
# 30910688             True  C_ID_0509e85404      322       False             1
#
#          category_3  merchant_category_id      merchant_id  month_lag  \
# 0                 A                    80  M_ID_e020e9b302         -8
# 1                 A                   367  M_ID_86ec983688         -7
# 2                 A                    80  M_ID_979ed661fc         -6
# 3                 A                   560  M_ID_e6d5ae8ea6         -5
# 4                 A                    80  M_ID_e020e9b302        -11
# 394               B                   278  M_ID_b61c7d1be0         -3
# 395               B                   307  M_ID_fe69229f24         -4
# 396               B                   705  M_ID_efc106141c         -9
# 397               B                   307  M_ID_708022307c         -4
# 398               B                   705  M_ID_393b4b8cec         -9
# 512               A                   879  M_ID_00a6ca8a8a         -1
# 513               A                   703  M_ID_4d6321ce13         -1
# 514               A                   683  M_ID_22360595e6        -11
# 515               A                   561  M_ID_67ead1197d         -3
# 516               A                   511  M_ID_0f8e964477        -10
# 790               B                   879  M_ID_9139332ccc         -2
# 791               B                   560  M_ID_2f6d08eaca         -8
# 792               B                   544  M_ID_7306a369ea         -8
# 793               B                   839  M_ID_50076f761c         -5
# 794               B                   278  M_ID_f86439cec0         -5
# 869               B                   879  M_ID_00a6ca8a8a         -5
# 870               B                   367  M_ID_68e26f3cca         -1
# 871               B                   879  M_ID_00a6ca8a8a         -2
# 872               C                   126  M_ID_25abfd10aa         -5
# 873               B                   309  M_ID_c2d9240309         -2
# 1110              A                   278  M_ID_8894ecfe89         -4
# 1111              A                   278  M_ID_cdabc86023         -7
# 1112              A                   111  M_ID_1440c83173        -13
# 1113              A                   367  M_ID_3339c5faa9         -9
# 1114              A                    80  M_ID_3214ef1be2         -9
# ...             ...                   ...              ...        ...
# 30906251          C                   544  M_ID_cdba603e7c          1
# 30906369          A                   840  M_ID_ca6128f3d8          1
# 30906392          B                   307  M_ID_559180aef0          1
# 30906410          B                   879  M_ID_9139332ccc          2
# 30906448          B                   302  M_ID_784417e169          1
# 30906449          B                   222  M_ID_7c0fb7f95c          2
# 30906455          B                   661  M_ID_fc7d7969c3          1
# 30907006          B                   705  M_ID_d3d9c017eb          2
# 30907213          C                   690  M_ID_3111c6df35          2
# 30907226          B                   705  M_ID_0e8d93dd86          2
# 30907328          A                   705  M_ID_77e2942cd8          2
# 30907818          B                   307  M_ID_a216ec6d06          1
# 30907965          B                   307  M_ID_3beb5cc157          2
# 30908033          A                   529  M_ID_8a7841faf9          1
# 30908050          A                   813  M_ID_b5e8daf772          1
# 30908382          B                   387  M_ID_1c6d0800e8          1
# 30908423          B                   661  M_ID_fc7d7969c3          2
# 30908662          C                   879  M_ID_00a6ca8a8a          2
# 30908663          B                   491  M_ID_79692349d6          1
# 30908831          C                   806  M_ID_44d0154c81          1
# 30909365          B                   661  M_ID_fc7d7969c3          1
# 30909562          B                   879  M_ID_9139332ccc          2
# 30909638          B                   302  M_ID_b9f9332438          1
# 30909806          A                   434  M_ID_f46a6367ca          1
# 30909948          A                   705  M_ID_d7d5019c60          1
# 30909976          B                   661  M_ID_fc7d7969c3          1
# 30909977          A                   307  M_ID_ef8673e53b          2
# 30910032          B                   879  M_ID_9139332ccc          1
# 30910126          D                   274  M_ID_e2f6434278          1
# 30910688          B                   705  M_ID_531bc3b325          2
#
#           purchase_amount     ...     avg_sales_lag3  avg_purchases_lag3  \
# 0               -0.703331     ...               1.08            1.082451
# 1               -0.733128     ...               1.06            1.052071
# 2               -0.720386     ...               0.98            0.974653
# 3               -0.735352     ...               1.00            1.053443
# 4               -0.722865     ...               1.08            1.082451
# 394             -0.595260     ...                NaN                 NaN
# 395              1.189469     ...                NaN                 NaN
# 396             -0.640069     ...                NaN                 NaN
# 397             -0.652256     ...                NaN                 NaN
# 398             -0.674210     ...                NaN                 NaN
# 512             -0.728876     ...                NaN                 NaN
# 513             -0.662759     ...                NaN                 NaN
# 514             -0.730379     ...               1.11            1.160071
# 515             -0.694315     ...                NaN                 NaN
# 516             -0.740146     ...                NaN                 NaN
# 790             -0.649837     ...                NaN                 NaN
# 791             -0.689206     ...               1.06            1.033645
# 792             -0.670378     ...               0.96            0.974946
# 793             -0.596793     ...               0.94            0.950611
# 794             -0.661407     ...               1.08            1.092926
# 869             -0.423838     ...                NaN                 NaN
# 870             -0.728876     ...                NaN                 NaN
# 871             -0.686802     ...                NaN                 NaN
# 872             -0.070715     ...               0.96            1.017007
# 873             -0.719860     ...               0.97            0.986310
# 1110            -0.733384     ...               4.66            4.214689
# 1111            -0.704263     ...                NaN                 NaN
# 1112            -0.717005     ...               1.47            1.330033
# 1113            -0.739485     ...               1.04            1.031947
# 1114            -0.736765     ...               0.98            1.005810
# ...                   ...     ...                ...                 ...
# 30906251        -0.577649     ...               0.74            0.805316
# 30906369        -0.617830     ...                NaN                 NaN
# 30906392        -0.646230     ...               1.11            1.098170
# 30906410        -0.734135     ...                NaN                 NaN
# 30906448        -0.431351     ...                NaN                 NaN
# 30906449        -0.475830     ...                NaN                 NaN
# 30906455        -0.717005     ...               0.88            0.890464
# 30907006        -0.708260     ...                NaN                 NaN
# 30907213        -0.146208     ...               0.95            0.997999
# 30907226        -0.603825     ...                NaN                 NaN
# 30907328        -0.714751     ...                NaN                 NaN
# 30907818        -0.731881     ...                NaN                 NaN
# 30907965        -0.566590     ...                NaN                 NaN
# 30908033        -0.686802     ...               0.97            1.107468
# 30908050        -0.686802     ...                NaN                 NaN
# 30908382        -0.431351     ...               0.96            0.994444
# 30908423        -0.746893     ...               0.88            0.890464
# 30908662        -0.701843     ...                NaN                 NaN
# 30908663        -0.461855     ...               0.95            0.828665
# 30908831         2.512793     ...               1.06            1.048276
# 30909365        -0.717005     ...               0.88            0.890464
# 30909562         1.777546     ...                NaN                 NaN
# 30909638         2.304706     ...                NaN                 NaN
# 30909806        -0.190927     ...                NaN                 NaN
# 30909948        -0.734887     ...               1.08            1.044870
# 30909976        -0.745405     ...               0.88            0.890464
# 30909977        -0.439135     ...               1.12            1.201715
# 30910032        -0.461434     ...                NaN                 NaN
# 30910126        -0.581616     ...                NaN                 NaN
# 30910688        -0.182166     ...                NaN                 NaN
#
#           active_months_lag3  avg_sales_lag6  avg_purchases_lag6  \
# 0                        3.0            1.14            1.114135
# 1                        3.0            1.06            1.058605
# 2                        3.0            0.98            0.967058
# 3                        3.0            0.88            0.897406
# 4                        3.0            1.14            1.114135
# 394                      NaN             NaN                 NaN
# 395                      NaN             NaN                 NaN
# 396                      NaN             NaN                 NaN
# 397                      NaN             NaN                 NaN
# 398                      NaN             NaN                 NaN
# 512                      NaN             NaN                 NaN
# 513                      NaN             NaN                 NaN
# 514                      3.0            1.13            1.174727
# 515                      NaN             NaN                 NaN
# 516                      NaN             NaN                 NaN
# 790                      NaN             NaN                 NaN
# 791                      3.0            1.03            1.004361
# 792                      3.0            0.99            0.998318
# 793                      3.0            0.94            0.930489
# 794                      3.0            1.09            1.095924
# 869                      NaN             NaN                 NaN
# 870                      NaN             NaN                 NaN
# 871                      NaN             NaN                 NaN
# 872                      3.0            1.12            1.299320
# 873                      3.0            1.07            1.007589
# 1110                     3.0            5.47            4.858757
# 1111                     NaN             NaN                 NaN
# 1112                     3.0            1.60            1.413641
# 1113                     3.0            1.02            1.007987
# 1114                     3.0            1.03            1.055963
# ...                      ...             ...                 ...
# 30906251                 3.0            0.67            0.728089
# 30906369                 NaN             NaN                 NaN
# 30906392                 3.0            1.03            1.079312
# 30906410                 NaN             NaN                 NaN
# 30906448                 NaN             NaN                 NaN
# 30906449                 NaN             NaN                 NaN
# 30906455                 3.0            0.72            0.737107
# 30907006                 NaN             NaN                 NaN
# 30907213                 3.0            0.90            0.967786
# 30907226                 NaN             NaN                 NaN
# 30907328                 NaN             NaN                 NaN
# 30907818                 NaN             NaN                 NaN
# 30907965                 NaN             NaN                 NaN
# 30908033                 3.0            0.79            0.888889
# 30908050                 NaN             NaN                 NaN
# 30908382                 3.0            3.38            1.602778
# 30908423                 3.0            0.72            0.737107
# 30908662                 NaN             NaN                 NaN
# 30908663                 3.0            0.88            0.724008
# 30908831                 3.0            1.14            1.021073
# 30909365                 3.0            0.72            0.737107
# 30909562                 NaN             NaN                 NaN
# 30909638                 NaN             NaN                 NaN
# 30909806                 NaN             NaN                 NaN
# 30909948                 3.0            1.06            1.020381
# 30909976                 3.0            0.72            0.737107
# 30909977                 3.0            1.11            1.260514
# 30910032                 NaN             NaN                 NaN
# 30910126                 NaN             NaN                 NaN
# 30910688                 NaN             NaN                 NaN
#
#           active_months_lag6  avg_sales_lag12 avg_purchases_lag12  \
# 0                        6.0             1.19            1.156844
# 1                        6.0             1.05            1.062087
# 2                        6.0             0.97            0.956668
# 3                        6.0             0.86            0.864394
# 4                        6.0             1.19            1.156844
# 394                      NaN              NaN                 NaN
# 395                      NaN              NaN                 NaN
# 396                      NaN              NaN                 NaN
# 397                      NaN              NaN                 NaN
# 398                      NaN              NaN                 NaN
# 512                      NaN              NaN                 NaN
# 513                      NaN              NaN                 NaN
# 514                      6.0             1.19            1.226067
# 515                      NaN              NaN                 NaN
# 516                      NaN              NaN                 NaN
# 790                      NaN              NaN                 NaN
# 791                      6.0             1.05            1.025078
# 792                      6.0             1.04            1.023464
# 793                      6.0             0.84            0.865628
# 794                      6.0             1.13            1.125829
# 869                      NaN              NaN                 NaN
# 870                      NaN              NaN                 NaN
# 871                      NaN              NaN                 NaN
# 872                      6.0             1.27            1.362148
# 873                      6.0             1.11            1.021705
# 1110                     6.0             5.70            4.977401
# 1111                     NaN              NaN                 NaN
# 1112                     6.0             1.60            1.407805
# 1113                     6.0             0.98            0.990977
# 1114                     6.0             1.12            1.151682
# ...                      ...              ...                 ...
# 30906251                 6.0             0.63            0.695881
# 30906369                 NaN              NaN                 NaN
# 30906392                 6.0             1.02            1.099972
# 30906410                 NaN              NaN                 NaN
# 30906448                 NaN              NaN                 NaN
# 30906449                 NaN              NaN                 NaN
# 30906455                 6.0             0.56            0.585596
# 30907006                 NaN              NaN                 NaN
# 30907213                 6.0             0.79            0.891154
# 30907226                 NaN              NaN                 NaN
# 30907328                 NaN              NaN                 NaN
# 30907818                 NaN              NaN                 NaN
# 30907965                 NaN              NaN                 NaN
# 30908033                 6.0             0.67            0.733607
# 30908050                 NaN              NaN                 NaN
# 30908382                 6.0             2.35            1.326389
# 30908423                 6.0             0.56            0.585596
# 30908662                 NaN              NaN                 NaN
# 30908663                 6.0             0.77            0.619400
# 30908831                 6.0             1.01            0.902107
# 30909365                 6.0             0.56            0.585596
# 30909562                 NaN              NaN                 NaN
# 30909638                 NaN              NaN                 NaN
# 30909806                 NaN              NaN                 NaN
# 30909948                 6.0             1.05            0.978475
# 30909976                 6.0             0.56            0.585596
# 30909977                 6.0             1.04            1.232969
# 30910032                 NaN              NaN                 NaN
# 30910126                 NaN              NaN                 NaN
# 30910688                 NaN              NaN                 NaN
#
#          active_months_lag12  category_4
# 0                       12.0        True
# 1                       12.0        True
# 2                       12.0        True
# 3                       12.0        True
# 4                       12.0        True
# 394                      NaN         NaN
# 395                      NaN         NaN
# 396                      NaN         NaN
# 397                      NaN         NaN
# 398                      NaN         NaN
# 512                      NaN         NaN
# 513                      NaN         NaN
# 514                     12.0        True
# 515                      NaN         NaN
# 516                      NaN         NaN
# 790                      NaN         NaN
# 791                     12.0        True
# 792                     12.0        True
# 793                     12.0        True
# 794                     12.0        True
# 869                      NaN         NaN
# 870                      NaN         NaN
# 871                      NaN         NaN
# 872                     12.0        True
# 873                     12.0        True
# 1110                    12.0       False
# 1111                     NaN         NaN
# 1112                    12.0       False
# 1113                    12.0       False
# 1114                    12.0       False
# ...                      ...         ...
# 30906251                 9.0        True
# 30906369                 NaN         NaN
# 30906392                12.0        True
# 30906410                 NaN         NaN
# 30906448                 NaN         NaN
# 30906449                 NaN         NaN
# 30906455                12.0        True
# 30907006                 NaN         NaN
# 30907213                12.0        True
# 30907226                 NaN         NaN
# 30907328                 NaN         NaN
# 30907818                 NaN         NaN
# 30907965                 NaN         NaN
# 30908033                12.0        True
# 30908050                 NaN         NaN
# 30908382                12.0        True
# 30908423                12.0        True
# 30908662                 NaN         NaN
# 30908663                12.0        True
# 30908831                12.0        True
# 30909365                12.0        True
# 30909562                 NaN         NaN
# 30909638                 NaN         NaN
# 30909806                 NaN         NaN
# 30909948                10.0        True
# 30909976                12.0        True
# 30909977                12.0       False
# 30910032                 NaN         NaN
# 30910126                 NaN         NaN
# 30910688                 NaN         NaN
#
# [1626990 rows x 29 columns]

# %%
gdf.isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-092b90ba1d07> in <module>()
# ----> 1 gdf.isnull().sum()
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in __getattr__(self, attr)
#     760             return self[attr]
#     761         if hasattr(self.obj, attr):
# --> 762             return self._make_wrapper(attr)
#     763
#     764         raise AttributeError("%r object has no attribute %r" %
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in _make_wrapper(self, name)
#     797                    "using the 'apply' method".format(kind, name,
#     798                                                      type(self).__name__))
# --> 799             raise AttributeError(msg)
#     800
#     801         self._set_group_selection()
#
# AttributeError: Cannot access callable attribute 'isnull' of 'DataFrameGroupBy' objects, try using the 'apply' method

# %% [markdown]
# #### Train

# %%
new_train_df = pd.merge(train_df, new_transactions_df, on="card_id", how="left")

# %%
new_train_df.head()

# %%
new_train_df.shape

# %%
new_train_df.isnull().sum()

# %%
new_train_df.drop_duplicates(inplace = True)

# %%
new_train_df.isnull().sum()

# %%
new_train_df.to_csv('(2)small_train.csv', index = False)

# %% [markdown]
# #### Test

# %%
new_test_df = pd.join(test, new_transactions_df, on="card_id", how="left")

# %%
new_test_df.head()

# %%
new_test_df.to_csv('(2)small_test.csv', index = False)
