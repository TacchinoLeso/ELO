# %%
import pandas as pd
import numpy as np
# Plot libraries
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.metrics import mean_squared_error
from math import sqrt

# Random seed for reproducibility
seed = 202
np.random.seed(seed)

# Ignore warnings
import warnings
warnings.simplefilter('ignore')

# Garbage collector
import gc
gc.enable()

# %%
# Import the preprocessed dataframes
train_df = pd.read_csv("(2)huge_train.csv")
test_df = pd.read_csv("(2)huge_test.csv")
train_df.shape, test_df.shape
# Out:
# ((19141554, 18), (11759740, 17))

# %%
train_df.head()
# Out:
#    authorized_flag          card_id  city_id  category_1  installments  \
# 0            False  C_ID_5037ff576e      322       False             1
# 1             True  C_ID_5037ff576e      138       False             1
# 2             True  C_ID_5037ff576e      138       False             1
# 3             True  C_ID_5037ff576e      226       False             1
# 4             True  C_ID_5037ff576e      330       False             1
#
#   category_3  merchant_category_id      merchant_id  month_lag  \
# 0          B                   278  M_ID_b61c7d1be0         -3
# 1          B                   307  M_ID_fe69229f24         -4
# 2          B                   705  M_ID_efc106141c         -9
# 3          B                   307  M_ID_708022307c         -4
# 4          B                   705  M_ID_393b4b8cec         -9
#
#    purchase_amount purchase_date  category_2  state_id  subsector_id  \
# 0        -0.595260    2017-09-07         3.0        11            37
# 1         1.189469    2017-08-14         1.0        15            19
# 2        -0.640069    2017-03-05         1.0        15            33
# 3        -0.652256    2017-08-15         1.0        16            19
# 4        -0.674210    2017-03-26         3.0        17            33
#
#    merchant_group_id most_recent_sales_range most_recent_purchases_range  \
# 0            91632.0                       D                           D
# 1            56893.0                       B                           C
# 2            21026.0                       D                           D
# 3            16621.0                       A                           B
# 4               35.0                       B                           B
#
#      target
# 0 -2.352713
# 1 -2.352713
# 2 -2.352713
# 3 -2.352713
# 4 -2.352713

# %%
cat_features = ['authorized_flag','city_id', 'category_1','category_3', 'merchant_category_id', 'merchant_id',
                'category_2', 'state_id', 'subsector_id', 'merchant_group_id', 'most_recent_sales_range', 'most_recent_purchases_range']
cont_features = ['installments', 'month_lag', 'purchase_amount']

# %%
# Input:
#    - df: input dataframe
#    - features_list: list of features on which apply tranformation
#    - time_list: time frames considered for each transformation
def categorical_features_eng(df, features_list, time_list):
    for feat_name in features_list:
        for time_name in time_list:
            new_feat_name = feat_name + '_'  + time_name
            df[new_feat_name] = df.groupby(time_name)[feat_name].transform('count')
    return df


def numerical_features_eng(df, features_list, time_list):
    for feat_name in features_list:
        for time_name in time_list:
            df[feat_name + '_' + time_name + '_mean'] = df.groupby(time_name)[feat_name].transform('mean')
            df[feat_name + '_' + time_name + '_max'] = df.groupby(time_name)[feat_name].transform('max')
            df[feat_name + '_' + time_name + '_min'] = df.groupby(time_name)[feat_name].transform('min')
            df[feat_name + '_' + time_name + '_sum'] = df.groupby(time_name)[feat_name].transform('sum')
            df[feat_name + '_' + time_name + '_std'] = df.groupby(time_name)[feat_name].transform('std')
    return df

# %%
def feature_engineering(df):
    df['purchase_date'] = pd.to_datetime(df['purchase_date'])
    
    df['day_of_week'] = df['purchase_date'].dt.dayofweek
    df['day_of_month'] = df['purchase_date'].dt.day
    df['week_of_year'] = df['purchase_date'].dt.weekofyear
    df['month'] = df['purchase_date'].dt.month
    
    time_list = ['day_of_week', 'day_of_month', 'week_of_year', 'month']
    categorical_features_eng(df, cat_features, ['purchase_date'])
    numerical_features_eng(df, cont_features, ['purchase_date'])
    
    return df

# %%
train_df = feature_engineering(train_df)
test_df = feature_engineering(test_df)
train_df.shape, test_df.shape
# Out:
# ((19141554, 49), (11759740, 48))

# %%
train_df.head()
# Out:
#    authorized_flag          card_id  city_id  category_1  installments  \
# 0            False  C_ID_5037ff576e      322       False             1
# 1             True  C_ID_5037ff576e      138       False             1
# 2             True  C_ID_5037ff576e      138       False             1
# 3             True  C_ID_5037ff576e      226       False             1
# 4             True  C_ID_5037ff576e      330       False             1
#
#   category_3  merchant_category_id      merchant_id  month_lag  \
# 0          B                   278  M_ID_b61c7d1be0         -3
# 1          B                   307  M_ID_fe69229f24         -4
# 2          B                   705  M_ID_efc106141c         -9
# 3          B                   307  M_ID_708022307c         -4
# 4          B                   705  M_ID_393b4b8cec         -9
#
#    purchase_amount                ...                  \
# 0        -0.595260                ...
# 1         1.189469                ...
# 2        -0.640069                ...
# 3        -0.652256                ...
# 4        -0.674210                ...
#
#   month_lag_purchase_date_mean  month_lag_purchase_date_max  \
# 0                    -4.239180                            2
# 1                    -5.059600                            2
# 2                    -8.787795                            1
# 3                    -5.071141                            2
# 4                    -8.874847                            1
#
#    month_lag_purchase_date_min  month_lag_purchase_date_sum  \
# 0                           -5                      -186295
# 1                           -6                      -209938
# 2                          -11                      -194553
# 3                           -6                      -211639
# 4                          -11                      -203376
#
#    month_lag_purchase_date_std purchase_amount_purchase_date_mean  \
# 0                     1.499793                           0.344795
# 1                     1.778255                          -0.468474
# 2                     3.402349                           0.082782
# 3                     1.761236                          -0.211578
# 4                     3.283712                           0.102100
#
#   purchase_amount_purchase_date_max  purchase_amount_purchase_date_min  \
# 0                      28402.554646                          -0.746893
# 1                       3324.656366                          -0.746893
# 2                      11119.097534                          -0.746893
# 3                      13374.780985                          -0.746893
# 4                      13587.446112                          -0.746893
#
#    purchase_amount_purchase_date_sum  purchase_amount_purchase_date_std
# 0                       15152.365035                         142.898114
# 1                      -19438.380727                          16.342966
# 2                        1832.715152                          76.753427
# 3                       -8829.988543                          65.689998
# 4                        2339.723108                          92.276168
#
# [5 rows x 49 columns]

# %%
train_df.isnull().sum()
# Out:
# authorized_flag                              0
# card_id                                      0
# city_id                                      0
# category_1                                   0
# installments                                 0
# category_3                                   0
# merchant_category_id                         0
# merchant_id                                  0
# month_lag                                    0
# purchase_amount                              0
# purchase_date                                0
# category_2                                   0
# state_id                                     0
# subsector_id                                 0
# merchant_group_id                            0
# most_recent_sales_range                      0
# most_recent_purchases_range                  0
# target                                       0
# day_of_week                                  0
# day_of_month                                 0
# week_of_year                                 0
# month                                        0
# authorized_flag_purchase_date                0
# city_id_purchase_date                        0
# category_1_purchase_date                     0
# category_3_purchase_date                     0
# merchant_category_id_purchase_date           0
# merchant_id_purchase_date                    0
# category_2_purchase_date                     0
# state_id_purchase_date                       0
# subsector_id_purchase_date                   0
# merchant_group_id_purchase_date              0
# most_recent_sales_range_purchase_date        0
# most_recent_purchases_range_purchase_date    0
# installments_purchase_date_mean              0
# installments_purchase_date_max               0
# installments_purchase_date_min               0
# installments_purchase_date_sum               0
# installments_purchase_date_std               0
# month_lag_purchase_date_mean                 0
# month_lag_purchase_date_max                  0
# month_lag_purchase_date_min                  0
# month_lag_purchase_date_sum                  0
# month_lag_purchase_date_std                  0
# purchase_amount_purchase_date_mean           0
# purchase_amount_purchase_date_max            0
# purchase_amount_purchase_date_min            0
# purchase_amount_purchase_date_sum            0
# purchase_amount_purchase_date_std            0
# dtype: int64

# %% [markdown]
# ### Export dataframes

# %%
train_df.to_csv('(3)eng_train.csv', index = False)
test_df.to_csv('(3)eng_test.csv', index = False)
