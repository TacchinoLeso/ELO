# %%
import os
import pandas as pd
import numpy as np
from collections import Counter

# Plot libraries
import matplotlib.pyplot as plt
import seaborn as sns
color = sns.color_palette()

# Random seed for reproducibility
seed = 202
np.random.seed(seed)

# Ignore warnings
import warnings
warnings.simplefilter('ignore')

# Garbage collector
import gc
gc.enable()

# %% [markdown]
# ### Import the dataframes

# %% [markdown]
# #### Train and test

# %%
# Train and test
train_df = pd.read_csv("(1)train.csv")
test_df = pd.read_csv("(1)test.csv")
train_df.shape, test_df.shape
# Out:
# ((201917, 7), (123623, 6))

# %%
train_df.head()
# Out:
#   first_active_month          card_id  feature_1  feature_2  feature_3  \
# 0         2017-06-01  C_ID_92a2005557          5          2          1
# 1         2017-01-01  C_ID_3d0044924f          4          1          0
# 2         2016-08-01  C_ID_d639edf6cd          2          2          0
# 3         2017-09-01  C_ID_186d6a6901          4          3          0
# 4         2017-11-01  C_ID_cdbd2c0db2          1          3          0
#
#      target  elapsed_time
# 0 -0.820283           245
# 1  0.392913           396
# 2  0.688056           549
# 3  0.142495           153
# 4 -0.159749            92

# %% [markdown]
# #### Transactions

# %%
transactions_df = pd.read_csv("(1)transactions.csv")
transactions_df.shape
# Out:
# (30910695, 28)

# %%
transactions_df.head()
# Out:
#    authorized_flag          card_id  city_id  category_1  installments  \
# 0             True  C_ID_4e6213e9bc       88       False             0
# 1             True  C_ID_4e6213e9bc       88       False             0
# 2             True  C_ID_4e6213e9bc       88       False             0
# 3             True  C_ID_4e6213e9bc       88       False             0
# 4             True  C_ID_4e6213e9bc       88       False             0
#
#    merchant_category_id      merchant_id  month_lag  purchase_amount  \
# 0                    80  M_ID_e020e9b302         -8        -0.703331
# 1                   367  M_ID_86ec983688         -7        -0.733128
# 2                    80  M_ID_979ed661fc         -6        -0.720386
# 3                   560  M_ID_e6d5ae8ea6         -5        -0.735352
# 4                    80  M_ID_e020e9b302        -11        -0.722865
#
#   purchase_date   ...     category_2_6.0  category_3_A  category_3_B  \
# 0    2017-06-25   ...                  0             1             0
# 1    2017-07-15   ...                  0             1             0
# 2    2017-08-09   ...                  0             1             0
# 3    2017-09-02   ...                  0             1             0
# 4    2017-03-10   ...                  0             1             0
#
#    category_3_C  category_3_D  day_of_week  day_of_month  week_of_year  month  \
# 0             0             0            6            25            25      6
# 1             0             0            5            15            28      7
# 2             0             0            2             9            32      8
# 3             0             0            5             2            35      9
# 4             0             0            4            10            10      3
#
#    weekend
# 0        1
# 1        1
# 2        0
# 3        1
# 4        0
#
# [5 rows x 28 columns]

# %% [markdown]
# #### Merchants

# %%
merchants_df = pd.read_csv("(1)merchants.csv")
merchants_df.shape
# Out:
# (334620, 22)

# %%
merchants_df.head()
# Out:
#        merchant_id  merchant_group_id  merchant_category_id  subsector_id  \
# 0  M_ID_838061e48c               8353                   792             9
# 1  M_ID_9339d880ad               3184                   840            20
# 2  M_ID_e726bbae1e                447                   690             1
# 3  M_ID_c929bb59af               9514                     2            20
# 4  M_ID_dd3ae3de10              30534                   278            37
#
#    numerical_1  numerical_2  category_1 most_recent_sales_range  \
# 0    -0.057471    -0.057471       False                       E
# 1    -0.057471    -0.057471       False                       E
# 2    -0.057471    -0.057471       False                       E
# 3    -0.057471    -0.057471       False                       E
# 4    -0.057471    -0.057471       False                       E
#
#   most_recent_purchases_range  avg_sales_lag3     ...      avg_sales_lag6  \
# 0                           E           -0.40     ...               -2.25
# 1                           E           -0.72     ...               -0.74
# 2                           E          -82.13     ...              -82.13
# 3                           E        69667.00     ...            69667.00
# 4                           E         5180.00     ...             9830.00
#
#    avg_purchases_lag6  active_months_lag6  avg_sales_lag12  \
# 0           18.666667                   6            -2.32
# 1            1.291667                   6            -0.57
# 2          260.000000                   2           -82.13
# 3            1.000000                   3         69667.00
# 4            4.166667                   6         15826.00
#
#    avg_purchases_lag12  active_months_lag12  category_4  city_id  state_id  \
# 0            13.916667                   12       False      242         9
# 1             1.687500                   12       False       22        16
# 2           260.000000                    2       False       -1         5
# 3             1.000000                    3       False       -1        20
# 4             5.600000                   10        True       11        23
#
#    category_2
# 0         1.0
# 1         1.0
# 2         5.0
# 3         5.0
# 4         2.0
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Transactions and Merchants dataframes merging

# %%
print("Number of common merchant_id in merchants_df and transactions_df: %d" % (len(set(transactions_df.merchant_id.unique()).intersection(set(merchants_df.merchant_id.unique())))))
print("merchants_df samples: %d, transactions_df samples: %d" % (merchants_df.shape[0], transactions_df.shape[0]))
# Out:
# Number of common merchant_id in merchants_df and transactions_df: 334620
# merchants_df samples: 334620, transactions_df samples: 30910695

# %%
for c in merchants_df.columns:
    if c not in transactions_df.columns:
        print(c)
# Out:
# merchant_group_id
# numerical_1
# numerical_2
# most_recent_sales_range
# most_recent_purchases_range
# avg_sales_lag3
# avg_purchases_lag3
# active_months_lag3
# avg_sales_lag6
# avg_purchases_lag6
# active_months_lag6
# avg_sales_lag12
# avg_purchases_lag12
# active_months_lag12
# category_4
# category_2

# %% [markdown]
# Actually, the only meaningfull features to be merged are merchant_group_id, most_recent_sales_range and most_recent_purchases_range

# %%
# here we can include more features

# %%
merchants_df = merchants_df[[
    "merchant_id", "merchant_group_id", "most_recent_sales_range", "most_recent_purchases_range",
    "avg_sales_lag3", "avg_purchases_lag3", "active_months_lag3", 
    "avg_sales_lag6", "avg_purchases_lag6", "active_months_lag6", 
    "avg_sales_lag12", "avg_purchases_lag12", "active_months_lag12"
]]
merchants_df.columns = [
    'id', "merchant_group_id", "most_recent_sales_range", "most_recent_purchases_range",
    "avg_sales_lag3", "avg_purchases_lag3", "active_months_lag3", 
    "avg_sales_lag6", "avg_purchases_lag6", "active_months_lag6", 
    "avg_sales_lag12", "avg_purchases_lag12", "active_months_lag12"
]
merchants_df.head()
# Out:
#                 id  merchant_group_id most_recent_sales_range  \
# 0  M_ID_838061e48c               8353                       E
# 1  M_ID_9339d880ad               3184                       E
# 2  M_ID_e726bbae1e                447                       E
# 3  M_ID_c929bb59af               9514                       E
# 4  M_ID_dd3ae3de10              30534                       E
#
#   most_recent_purchases_range  avg_sales_lag3  avg_purchases_lag3  \
# 0                           E           -0.40            9.666667
# 1                           E           -0.72            1.750000
# 2                           E          -82.13          260.000000
# 3                           E        69667.00            1.000000
# 4                           E         5180.00            4.000000
#
#    active_months_lag3  avg_sales_lag6  avg_purchases_lag6  active_months_lag6  \
# 0                   3           -2.25           18.666667                   6
# 1                   3           -0.74            1.291667                   6
# 2                   2          -82.13          260.000000                   2
# 3                   3        69667.00            1.000000                   3
# 4                   3         9830.00            4.166667                   6
#
#    avg_sales_lag12  avg_purchases_lag12  active_months_lag12
# 0            -2.32            13.916667                   12
# 1            -0.57             1.687500                   12
# 2           -82.13           260.000000                    2
# 3         69667.00             1.000000                    3
# 4         15826.00             5.600000                   10

# %%
trans_merch_df = transactions_df.merge(merchants_df, how='left', left_on='merchant_id', right_on='id')
trans_merch_df = trans_merch_df.drop(['id'], axis=1)
trans_merch_df.shape
# Out:
# (30910695, 40)

# %%
trans_merch_df.head(10)
# Out:
#    authorized_flag          card_id  city_id  category_1  installments  \
# 0             True  C_ID_4e6213e9bc       88       False             0
# 1             True  C_ID_4e6213e9bc       88       False             0
# 2             True  C_ID_4e6213e9bc       88       False             0
# 3             True  C_ID_4e6213e9bc       88       False             0
# 4             True  C_ID_4e6213e9bc       88       False             0
# 5             True  C_ID_4e6213e9bc      333       False             0
# 6             True  C_ID_4e6213e9bc       88       False             0
# 7             True  C_ID_4e6213e9bc        3       False             0
# 8             True  C_ID_4e6213e9bc       88       False             0
# 9             True  C_ID_4e6213e9bc       88       False             0
#
#    merchant_category_id      merchant_id  month_lag  purchase_amount  \
# 0                    80  M_ID_e020e9b302         -8        -0.703331
# 1                   367  M_ID_86ec983688         -7        -0.733128
# 2                    80  M_ID_979ed661fc         -6        -0.720386
# 3                   560  M_ID_e6d5ae8ea6         -5        -0.735352
# 4                    80  M_ID_e020e9b302        -11        -0.722865
# 5                    80  M_ID_50af771f8d          0        -0.734887
# 6                   278  M_ID_5e8220e564        -11        -0.716855
# 7                    80  M_ID_9d41786a50         -3        -0.657049
# 8                    80  M_ID_979ed661fc         -8        -0.737967
# 9                    80  M_ID_74ba14b5fc        -11        -0.715352
#
#   purchase_date         ...           most_recent_purchases_range  \
# 0    2017-06-25         ...                                     A
# 1    2017-07-15         ...                                     A
# 2    2017-08-09         ...                                     C
# 3    2017-09-02         ...                                     C
# 4    2017-03-10         ...                                     A
# 5    2018-02-24         ...                                     A
# 6    2017-03-21         ...                                     A
# 7    2017-11-18         ...                                     C
# 8    2017-06-01         ...                                     C
# 9    2017-03-16         ...                                     C
#
#    avg_sales_lag3  avg_purchases_lag3  active_months_lag3  avg_sales_lag6  \
# 0            1.08            1.082451                 3.0            1.14
# 1            1.06            1.052071                 3.0            1.06
# 2            0.98            0.974653                 3.0            0.98
# 3            1.00            1.053443                 3.0            0.88
# 4            1.08            1.082451                 3.0            1.14
# 5            0.98            1.019285                 3.0            0.94
# 6            1.11            1.108094                 3.0            1.16
# 7            1.06            1.075861                 3.0            1.08
# 8            0.98            0.974653                 3.0            0.98
# 9            0.96            0.975325                 3.0            1.02
#
#    avg_purchases_lag6  active_months_lag6  avg_sales_lag12  \
# 0            1.114135                 6.0             1.19
# 1            1.058605                 6.0             1.05
# 2            0.967058                 6.0             0.97
# 3            0.897406                 6.0             0.86
# 4            1.114135                 6.0             1.19
# 5            0.961773                 6.0             0.97
# 6            1.156869                 6.0             1.22
# 7            1.098235                 6.0             1.10
# 8            0.967058                 6.0             0.97
# 9            0.947403                 6.0             1.09
#
#    avg_purchases_lag12  active_months_lag12
# 0             1.156844                 12.0
# 1             1.062087                 12.0
# 2             0.956668                 12.0
# 3             0.864394                 12.0
# 4             1.156844                 12.0
# 5             0.982693                 12.0
# 6             1.208972                 12.0
# 7             1.104590                 12.0
# 8             0.956668                 12.0
# 9             0.977381                 12.0
#
# [10 rows x 40 columns]

# %%
trans_merch_df.isnull().sum()
# Out:
# authorized_flag                   0
# card_id                           0
# city_id                           0
# category_1                        0
# installments                      0
# merchant_category_id              0
# merchant_id                       0
# month_lag                         0
# purchase_amount                   0
# purchase_date                     0
# state_id                          0
# subsector_id                      0
# month_diff                        0
# category_2_1.0                    0
# category_2_2.0                    0
# category_2_3.0                    0
# category_2_4.0                    0
# category_2_5.0                    0
# category_2_6.0                    0
# category_3_A                      0
# category_3_B                      0
# category_3_C                      0
# category_3_D                      0
# day_of_week                       0
# day_of_month                      0
# week_of_year                      0
# month                             0
# weekend                           0
# merchant_group_id              9401
# most_recent_sales_range        9401
# most_recent_purchases_range    9401
# avg_sales_lag3                 9401
# avg_purchases_lag3             9401
# active_months_lag3             9401
# avg_sales_lag6                 9401
# avg_purchases_lag6             9401
# active_months_lag6             9401
# avg_sales_lag12                9401
# avg_purchases_lag12            9401
# active_months_lag12            9401
# dtype: int64

# %%
trans_merch_df.dropna(inplace=True)
trans_merch_df.shape
# Out:
# (30901294, 40)

# %%
# %%time
# This function can be used to compute the mode with groupby()
# prova = trans_merch_df.groupby('card_id')['city_id'].apply(lambda x: x.mode())
# Out:
# Wall time: 0 ns

# %% [markdown]
# ## Merge transactions in train and test

# %%
print("Number of common card_id in train_df and trans_merch_df: %d" % (len(set(trans_merch_df.card_id.unique()).intersection(set(train_df.card_id.unique())))))
print("train_df samples: %d, trans_merch_df samples: %d" % (train_df.shape[0], trans_merch_df.shape[0]))

print("Number of common card_id in test_df and trans_merch_df: %d" % (len(set(trans_merch_df.card_id.unique()).intersection(set(test_df.card_id.unique())))))
print("test_df samples: %d, trans_merch_df samples: %d" % (test_df.shape[0], trans_merch_df.shape[0]))
# Out:
# Number of common card_id in train_df and trans_merch_df: 201917
# train_df samples: 201917, trans_merch_df samples: 30901294
# Number of common card_id in test_df and trans_merch_df: 123623
# test_df samples: 123623, trans_merch_df samples: 30901294

# %%
def binary_aggregation(df, new_df, columns):
    for col in columns:
        new_df[col + '_sum'] = df.groupby("card_id")[col].sum()
        new_df[col + '_mean'] = df.groupby("card_id")[col].mean()
    return new_df

def categorical_aggregation(df, new_df, columns):
    for col in columns:
        new_df[col + '_nunique'] = df.groupby('card_id')[col].nunique()
    return new_df

def numerical_aggregation(df, new_df, columns):
    for col in columns:
        new_df[col + '_sum'] = df.groupby('card_id')[col].sum()
        new_df[col + '_mean'] = df.groupby('card_id')[col].mean()
        new_df[col + '_max'] = df.groupby('card_id')[col].max()
        new_df[col + '_min'] = df.groupby('card_id')[col].min()
    return new_df

# %%
prova = pd.DataFrame()
feature = [        "avg_sales_lag6", "avg_purchases_lag6", "active_months_lag6", 
        "avg_sales_lag12", "avg_purchases_lag12", "active_months_lag12"]
prova = numerical_aggregation(trans_merch_df, prova, feature)
prova['trans_card_id'] = prova.index
# 325539                   522.0                 6.000000       ...
#
#         avg_sales_lag12_min  avg_purchases_lag12_sum  \
# 0                      0.54               167.780254
# 1                      0.53               740.656505
# 2                      0.76                74.227565
# 3                      0.50              1095.170371
# 4                      0.63              1277.622445
# 5                      0.76                79.787424
# 6                      0.65               172.344363
# 7                      0.76                41.789544
# 8                      0.76                32.654289
# 9                      0.47                73.173270
# 10                     0.53               200.994508
# 11                     0.36               157.346928
# 12                     0.76                46.744988
# 13                     0.73                33.207573
# 14                     0.53              2398.539231
# 15                     0.66              2001.343737
# 16                     0.65                47.292670
# 17                     0.76                13.722968
# 18                     0.53                80.820745
# 19                     0.62                46.860457
# 20                     0.62               125.238715
# 21                     0.37               100.338787
# 22                     0.53               102.257173
# 23                     0.47                44.994367
# 24                     0.92                17.029440
# 25                     0.61                 8.025994
# 26                     0.41               751.475247
# 27                     0.56                97.971723
# 28                     0.61                50.452892
# 29                     0.76               602.299003
# ...                     ...                      ...
# 325510                 0.60                21.571182
# 325511                 0.62                57.844667
# 325512                 0.76                85.363016
# 325513                 0.53               135.843766
# 325514                 0.54                28.027246
# 325515                 0.37              3077.588868
# 325516                 0.25               113.926925
# 325517                 0.67                51.575968
# 325518                 0.69                67.415318
# 325519                 0.53              2025.993914
# 325520                 0.32                23.767624
# 325521                 0.56                34.993547
# 325522                 0.52                81.073712
# 325523                 0.42               297.794169
# 325524                 0.49               153.191915
# 325525                 0.62                73.296018
# 325526                 0.53              7339.745728
# 325527                 0.52                81.862682
# 325528                 0.84                61.284693
# 325529                 0.58              1216.222773
# 325530                 0.53              1127.474080
# 325531                 0.72               108.929174
# 325532                 0.53              2691.732971
# 325533                 0.56               144.205279
# 325534                 0.32              3007.761039
# 325535                 0.65                15.219952
# 325536                 0.50              1252.127376
# 325537                 0.68                28.227443
# 325538                 0.56               776.441606
# 325539                 0.56                85.518513
#
#         avg_purchases_lag12_mean  avg_purchases_lag12_max  \
# 0                       1.111128                 3.441176
# 1                       5.004436               554.397813
# 2                       1.107874                 1.516779
# 3                       4.433888               554.397813
# 4                       8.242725               554.397813
# 5                       1.139820                 2.578018
# 6                       2.267689                16.393939
# 7                       0.994989                 1.191317
# 8                       1.053364                 2.798186
# 9                       1.002374                 2.335497
# 10                      2.753349               119.916667
# 11                      1.035177                 2.973485
# 12                      1.263378                14.448582
# 13                      1.145089                 2.619048
# 14                     13.551069               554.397813
# 15                      7.552241               554.397813
# 16                      0.738948                 1.262387
# 17                      0.914865                 1.098737
# 18                      1.049620                 2.686367
# 19                      1.089778                 1.450520
# 20                     17.891245               119.916667
# 21                      1.337850                19.666667
# 22                      2.840477                31.391667
# 23                      1.022599                 2.570418
# 24                      1.064340                 1.321206
# 25                      1.003249                 2.019380
# 26                      4.848227               554.397813
# 27                      1.113315                 1.703250
# 28                      1.173323                 2.274020
# 29                     14.006954               554.397813
# ...                          ...                      ...
# 325510                  0.980508                 1.107886
# 325511                  0.997322                 1.480583
# 2                      12.000000                     12.0
# 3                      11.963563                     12.0
# 4                      11.980645                     12.0
# 5                      12.000000                     12.0
# 6                      11.894737                     12.0
# 7                      12.000000                     12.0
# 8                      12.000000                     12.0
# 9                      12.000000                     12.0
# 10                     11.972603                     12.0
# 11                     11.986842                     12.0
# 12                     12.000000                     12.0
# 13                     12.000000                     12.0
# 14                     11.632768                     12.0
# 15                     11.984906                     12.0
# 16                     12.000000                     12.0
# 17                     12.000000                     12.0
# 18                     11.974026                     12.0
# 19                     12.000000                     12.0
# 20                     12.000000                     12.0
# 21                     11.906667                     12.0
# 22                     11.944444                     12.0
# 23                     12.000000                     12.0
# 24                     12.000000                     12.0
# 25                     12.000000                     12.0
# 26                     11.961290                     12.0
# 27                     12.000000                     12.0
# 28                     12.000000                     12.0
# 29                     12.000000                     12.0
# ...                          ...                      ...
# 325510                 12.000000                     12.0
# 325511                 12.000000                     12.0
# 325512                 11.951807                     12.0
# 325513                 12.000000                     12.0
# 325514                 11.703704                     12.0
# 325515                 11.959091                     12.0
# 325516                 11.767857                     12.0
# 325517                 11.742857                     12.0
# 325518                 12.000000                     12.0
# 325519                 11.997503                     12.0
# 325520                 11.739130                     12.0
# 325521                 12.000000                     12.0
# 325522                 11.951220                     12.0
# 325523                 11.941860                     12.0
# 325524                 11.938776                     12.0
# 325525                 12.000000                     12.0
# 325526                 11.910448                     12.0
# 325527                 11.939759                     12.0
# 325528                 12.000000                     12.0
# 325529                 11.956044                     12.0
# 325530                 11.983240                     12.0
# 325531                 11.924242                     12.0
# 325532                 11.973366                     12.0
# 325533                 12.000000                     12.0
# 325534                 11.901869                     12.0
# 325535                 12.000000                     12.0
# 325536                 11.756522                     12.0
# 325537                 12.000000                     12.0
# 325538                 11.964646                     12.0
# 325539                 12.000000                     12.0
#
#         active_months_lag12_min    trans_card_id
# 0                           9.0  C_ID_00007093c1
# 1                          10.0  C_ID_0001238066
# 2                          12.0  C_ID_0001506ef0
# 3                           9.0  C_ID_0001793786
# 4                           9.0  C_ID_000183fdda
# 5                          12.0  C_ID_00024e244b
# 6                           8.0  C_ID_0002709b5a
# 7                          12.0  C_ID_00027503e2
# 8                          12.0  C_ID_000298032a
# 9                          12.0  C_ID_0002ba3c2e
# 10                         10.0  C_ID_0002c7c2c1
# 11                         10.0  C_ID_00032df08f
# 12                         12.0  C_ID_0003754056
# 13                         12.0  C_ID_000377f6a0
# 14                          5.0  C_ID_0003be3c83
# 15                          9.0  C_ID_0003f41435
# 16                         12.0  C_ID_00042d509c
# 17                         12.0  C_ID_0004587331
# 18                         10.0  C_ID_0004725b87
# 19                         12.0  C_ID_0004888ddd
# 20                         12.0  C_ID_0004b68c49
# 21                         10.0  C_ID_0004c2a5ab
# 22                         10.0  C_ID_00057b99fe
# 23                         12.0  C_ID_000599daf9
# 24                         12.0  C_ID_0005b2f279
# 25                         12.0  C_ID_0005b5804f
# 26                          6.0  C_ID_0005f16cc8
# 27                         12.0  C_ID_0006152db8
# 28                         12.0  C_ID_000616f4a8
# 29                         12.0  C_ID_000664aa02
# ...                         ...              ...
# 325510                     12.0  C_ID_fffb79fb56
# 325511                     12.0  C_ID_fffb9ea3f6
# 325512                     10.0  C_ID_fffba72dc5
# 325513                     12.0  C_ID_fffbdf036b
# 325514                      8.0  C_ID_fffbee5c24
# 325515                      7.0  C_ID_fffc96bf24
# 325516                      4.0  C_ID_fffcb74f49
# 325517                      3.0  C_ID_fffcf66e12
# 325518                     12.0  C_ID_fffd070e0e
# 325519                     10.0  C_ID_fffd1207a8
# 325520                      6.0  C_ID_fffd24dcf3
# 325521                     12.0  C_ID_fffd337484
# 325522                     10.0  C_ID_fffd345048
# 325523                      8.0  C_ID_fffd351e7f
# 325524                      9.0  C_ID_fffd93c8bf
# 325525                     12.0  C_ID_fffd943b91
# 325526                      7.0  C_ID_fffdad8aa0
# 325527                      7.0  C_ID_fffde15ab6
# 325528                     12.0  C_ID_fffdf34798
# 325529                     10.0  C_ID_fffe29a04a
# 325530                      6.0  C_ID_fffe78b232
# 325531                      7.0  C_ID_fffe866457
# 325532                      8.0  C_ID_fffea6de74
# 325533                     12.0  C_ID_fffeced303
# 325534                      9.0  C_ID_fffeed3a89
# 325535                     12.0  C_ID_ffff1d9928
# 325536                      8.0  C_ID_ffff579d3a
# 325537                     12.0  C_ID_ffff756266
# 325538                      8.0  C_ID_ffff828181
# 325539                     12.0  C_ID_fffffd5772
#
# [325540 rows x 25 columns]

# %%
prova.shape
# Out:
# (325540, 29)

# %%
def aggregate_transaction_merchant_per_card_id(df):
    
    new_df = pd.DataFrame()
    
    # card_id
    new_df['transactions_count'] = df.groupby("card_id")['card_id'].count()
 
    binary_features = [
        "authorized_flag", "category_1", 
        "category_2_1.0", "category_2_2.0", "category_2_3.0", "category_2_4.0", "category_2_5.0", "category_2_6.0", 
        "category_3_A", "category_3_B", "category_3_C", "category_3_D", 
        "weekend"
    ]

    categorical_features = [
        "merchant_category_id", "merchant_id", "merchant_group_id",
        "purchase_date", "state_id", "subsector_id", 
        "day_of_week", "day_of_month", "week_of_year", "month",  
        "most_recent_sales_range", "most_recent_purchases_range"
    ]

    numerical_features = [
        "installments", "month_lag", "purchase_amount", "month_diff",
        "avg_sales_lag3", "avg_purchases_lag3", "active_months_lag3", 
        "avg_sales_lag6", "avg_purchases_lag6", "active_months_lag6", 
        "avg_sales_lag12", "avg_purchases_lag12", "active_months_lag12"
    ]
    
    new_df = binary_aggregation(df, new_df, binary_features)
    new_df = categorical_aggregation(df, new_df, categorical_features)
    new_df = numerical_aggregation(df, new_df, numerical_features)
    
    # Special features
    new_df['purchase_date_min'] = df.groupby('card_id')['purchase_date'].min()
    new_df['purchase_date_max'] = df.groupby('card_id')['purchase_date'].max()
    new_df['month_lag_std'] = df.groupby('card_id')['month_lag'].std()

    new_df['trans_card_id'] = new_df.index
    new_df = new_df.reset_index(drop=True)
    return new_df

# %%
grouped_df = aggregate_transaction_merchant_per_card_id(trans_merch_df)
grouped_df.head()
# Out:
#    transactions_count  authorized_flag_sum  authorized_flag_mean  \
# 0                 151                116.0              0.768212
# 1                 148                145.0              0.979730
# 2                  67                 63.0              0.940299
# 3                 247                220.0              0.890688
# 4                 155                148.0              0.954839
#
#    category_1_sum  category_1_mean  category_2_1.0_sum  category_2_1.0_mean  \
# 0            28.0         0.185430                   1             0.006623
# 1             4.0         0.027027                 115             0.777027
# 2             0.0         0.000000                   2             0.029851
# 3             2.0         0.008097                  26             0.105263
# 4             4.0         0.025806                   7             0.045161
#
#    category_2_2.0_sum  category_2_2.0_mean  category_2_3.0_sum  \
# 0                   0             0.000000                 121
# 1                   0             0.000000                   0
# 2                   0             0.000000                  65
# 3                  84             0.340081                  20
# 4                   1             0.006452                 142
#
#         ...         avg_purchases_lag12_max  avg_purchases_lag12_min  \
# 0       ...                        3.441176                 0.549837
# 1       ...                      554.397813                 0.540334
# 2       ...                        1.516779                 0.752641
# 3       ...                      554.397813                 0.438104
# 4       ...                      554.397813                 0.564815
#
#    active_months_lag12_sum  active_months_lag12_mean  active_months_lag12_max  \
# 0                   1800.0                 11.920530                     12.0
# 1                   1773.0                 11.979730                     12.0
# 2                    804.0                 12.000000                     12.0
# 3                   2955.0                 11.963563                     12.0
# 4                   1857.0                 11.980645                     12.0
#
#    active_months_lag12_min  purchase_date_min  purchase_date_max  \
# 0                      9.0         2017-02-14         2018-04-09
# 1                     10.0         2017-09-28         2018-04-30
# 2                     12.0         2017-01-14         2018-03-22
# 3                      9.0         2017-01-21         2017-12-31
# 4                      9.0         2017-08-07         2018-04-30
#
#    month_lag_std    trans_card_id
# 0       3.546301  C_ID_00007093c1
# 1       1.685557  C_ID_0001238066
# 2       4.265234  C_ID_0001506ef0
# 3       2.657197  C_ID_0001793786
# 4       2.066389  C_ID_000183fdda
#
# [5 rows x 95 columns]

# %% [markdown]
# #### Train

# %%
train_small_df = train_df.merge(grouped_df, how='left', left_on='card_id', right_on='trans_card_id')
train_small_df = train_small_df.drop(['trans_card_id'], axis=1)
train_small_df.shape
# Out:
# (201917, 101)

# %%
train_small_df.head()
# Out:
#   first_active_month          card_id  feature_1  feature_2  feature_3  \
# 0         2017-06-01  C_ID_92a2005557          5          2          1
# 1         2017-01-01  C_ID_3d0044924f          4          1          0
# 2         2016-08-01  C_ID_d639edf6cd          2          2          0
# 3         2017-09-01  C_ID_186d6a6901          4          3          0
# 4         2017-11-01  C_ID_cdbd2c0db2          1          3          0
#
#      target  elapsed_time  transactions_count  authorized_flag_sum  \
# 0 -0.820283           245                 277                265.0
# 1  0.392913           396                 356                345.0
# 2  0.688056           549                  44                 42.0
# 3  0.142495           153                  84                 84.0
# 4 -0.159749            92                 168                163.0
#
#    authorized_flag_mean      ...        avg_purchases_lag12_mean  \
# 0              0.956679      ...                       21.523449
# 1              0.969101      ...                        4.282934
# 2              0.954545      ...                        1.059354
# 3              1.000000      ...                        1.027061
# 4              0.970238      ...                        4.669668
#
#    avg_purchases_lag12_max  avg_purchases_lag12_min  active_months_lag12_sum  \
# 0               554.397813                 0.252963                   3313.0
# 1               554.397813                 0.209035                   4266.0
# 2                 1.541667                 0.752641                    526.0
# 3                 1.835911                 0.436002                   1004.0
# 4               554.397813                 0.286437                   2003.0
#
#    active_months_lag12_mean  active_months_lag12_max  active_months_lag12_min  \
# 0                 11.960289                     12.0                      5.0
# 1                 11.983146                     12.0                     10.0
# 2                 11.954545                     12.0                     10.0
# 3                 11.952381                     12.0                     10.0
# 4                 11.922619                     12.0                      5.0
#
#    purchase_date_min  purchase_date_max  month_lag_std
# 0         2017-06-27         2018-04-29       2.727337
# 1         2017-01-06         2018-03-30       3.865994
# 2         2017-01-11         2018-04-28       4.120798
# 3         2017-09-26         2018-04-18       2.141977
# 4         2017-11-12         2018-04-28       1.501781
#
# [5 rows x 101 columns]

# %%
train_small_df.isnull().sum()
# Out:
# first_active_month          0
# card_id                     0
# feature_1                   0
# feature_2                   0
# feature_3                   0
# target                      0
# elapsed_time                0
# transactions_count          0
# authorized_flag_sum         0
# authorized_flag_mean        0
# category_1_sum              0
# category_1_mean             0
# category_2_1.0_sum          0
# category_2_1.0_mean         0
# category_2_2.0_sum          0
# category_2_2.0_mean         0
# category_2_3.0_sum          0
# category_2_3.0_mean         0
# category_2_4.0_sum          0
# category_2_4.0_mean         0
# category_2_5.0_sum          0
# category_2_5.0_mean         0
# category_2_6.0_sum          0
# category_2_6.0_mean         0
# category_3_A_sum            0
# category_3_A_mean           0
# category_3_B_sum            0
# category_3_B_mean           0
# category_3_C_sum            0
# category_3_C_mean           0
#                            ..
# active_months_lag3_mean     0
# active_months_lag3_max      0
# active_months_lag3_min      0
# avg_sales_lag6_sum          0
# avg_sales_lag6_mean         0
# avg_sales_lag6_max          0
# avg_sales_lag6_min          0
# avg_purchases_lag6_sum      0
# avg_purchases_lag6_mean     0
# avg_purchases_lag6_max      0
# avg_purchases_lag6_min      0
# active_months_lag6_sum      0
# active_months_lag6_mean     0
# active_months_lag6_max      0
# active_months_lag6_min      0
# avg_sales_lag12_sum         0
# avg_sales_lag12_mean        0
# avg_sales_lag12_max         0
# avg_sales_lag12_min         0
# avg_purchases_lag12_sum     0
# avg_purchases_lag12_mean    0
# avg_purchases_lag12_max     0
# avg_purchases_lag12_min     0
# active_months_lag12_sum     0
# active_months_lag12_mean    0
# active_months_lag12_max     0
# active_months_lag12_min     0
# purchase_date_min           0
# purchase_date_max           0
# month_lag_std               0
# Length: 101, dtype: int64

# %% [markdown]
# #### Test

# %%
test_small_df = test_df.merge(grouped_df, how='left', left_on='card_id', right_on='trans_card_id')
test_small_df = test_small_df.drop(['trans_card_id'], axis=1)
test_small_df.shape
# Out:
# (123623, 100)

# %%
test_small_df.head()
# Out:
#   first_active_month          card_id  feature_1  feature_2  feature_3  \
# 0         2017-04-01  C_ID_0ab67a22ab          3          3          1
# 1         2017-01-01  C_ID_130fd0cbdd          2          3          0
# 2         2017-08-01  C_ID_b709037bc5          5          1          1
# 3         2017-12-01  C_ID_d27d835a9f          2          1          0
# 4         2015-12-01  C_ID_2b5e3df5c2          5          1          1
#
#    elapsed_time  transactions_count  authorized_flag_sum  \
# 0         306.0                  71                 47.0
# 1         396.0                  87                 86.0
# 2         184.0                  15                 11.0
# 3          62.0                  36                 36.0
# 4         793.0                 116                 93.0
#
#    authorized_flag_mean  category_1_sum      ...        \
# 0              0.661972            23.0      ...
# 1              0.988506             4.0      ...
# 2              0.733333             2.0      ...
# 3              1.000000             1.0      ...
# 4              0.801724             0.0      ...
#
#    avg_purchases_lag12_mean  avg_purchases_lag12_max  avg_purchases_lag12_min  \
# 0                  0.995958                 6.346154                 0.584000
# 1                  1.069059                 4.247402                 0.710589
# 2                  1.104988                 1.452443                 0.584000
# 3                  1.069105                 1.327300                 0.584000
# 4                  2.473774                95.666667                 0.540334
#
#    active_months_lag12_sum  active_months_lag12_mean  active_months_lag12_max  \
# 0                    852.0                 12.000000                     12.0
# 1                   1040.0                 11.954023                     12.0
# 2                    180.0                 12.000000                     12.0
# 3                    432.0                 12.000000                     12.0
# 4                   1365.0                 11.767241                     12.0
#
#    active_months_lag12_min  purchase_date_min  purchase_date_max  \
# 0                     12.0         2017-04-04         2018-02-28
# 1                      8.0         2017-01-13         2018-04-20
# 2                     12.0         2017-08-25         2018-03-13
# 3                     12.0         2017-12-04         2018-04-17
# 4                      7.0         2017-01-03         2018-04-12
#
#    month_lag_std
# 0       2.659102
# 1       4.172247
# 2       1.951800
# 3       1.424001
# 4       4.708186
#
# [5 rows x 100 columns]

# %%
test_small_df.isnull().sum()
# Out:
# first_active_month          0
# card_id                     0
# feature_1                   0
# feature_2                   0
# feature_3                   0
# elapsed_time                0
# transactions_count          0
# authorized_flag_sum         0
# authorized_flag_mean        0
# category_1_sum              0
# category_1_mean             0
# category_2_1.0_sum          0
# category_2_1.0_mean         0
# category_2_2.0_sum          0
# category_2_2.0_mean         0
# category_2_3.0_sum          0
# category_2_3.0_mean         0
# category_2_4.0_sum          0
# category_2_4.0_mean         0
# category_2_5.0_sum          0
# category_2_5.0_mean         0
# category_2_6.0_sum          0
# category_2_6.0_mean         0
# category_3_A_sum            0
# category_3_A_mean           0
# category_3_B_sum            0
# category_3_B_mean           0
# category_3_C_sum            0
# category_3_C_mean           0
# category_3_D_sum            0
#                            ..
# active_months_lag3_mean     0
# active_months_lag3_max      0
# active_months_lag3_min      0
# avg_sales_lag6_sum          0
# avg_sales_lag6_mean         0
# avg_sales_lag6_max          0
# avg_sales_lag6_min          0
# avg_purchases_lag6_sum      0
# avg_purchases_lag6_mean     0
# avg_purchases_lag6_max      0
# avg_purchases_lag6_min      0
# active_months_lag6_sum      0
# active_months_lag6_mean     0
# active_months_lag6_max      0
# active_months_lag6_min      0
# avg_sales_lag12_sum         0
# avg_sales_lag12_mean        0
# avg_sales_lag12_max         0
# avg_sales_lag12_min         0
# avg_purchases_lag12_sum     0
# avg_purchases_lag12_mean    0
# avg_purchases_lag12_max     0
# avg_purchases_lag12_min     0
# active_months_lag12_sum     0
# active_months_lag12_mean    0
# active_months_lag12_max     0
# active_months_lag12_min     0
# purchase_date_min           0
# purchase_date_max           0
# month_lag_std               0
# Length: 100, dtype: int64

# %% [markdown]
# ### Export small dataframes

# %%
train_small_df.to_csv('(2)small_train.csv', index = False)
test_small_df.to_csv('(2)small_test.csv', index = False)
